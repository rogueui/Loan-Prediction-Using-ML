# %% [markdown]
# # Inflation_Calculator: `Web Scrapping`
#
# ## Table of Content
# [A. Data Gathering](#gather)\
# [B. Data Cleaning](#clean)

# %%
# Mounting the Google Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# <a id = 'gather'></a>
# ## A. Data Gathering

# %%
# Importing Libraries

from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# Getting URL

url = 'https://www.macrotrends.net/countries/IND/india/inflation-rate-cpi'

html_content = requests.get(url).text

# %%
# URL Content

soup = BeautifulSoup(html_content, "lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <link href="https://www.macrotrends.net/countries/IND/india/inflation-rate-cpi" rel="canonical"/>
#   <title>
#    India Inflation Rate 1960-2020 | MacroTrends
#   </title>
#   <meta content="Inflation as measured by the consumer price index reflects the annual percentage change in the cost to the average consumer of acquiring a basket of goods and services that may be fixed or changed at specified intervals, such as yearly. The Laspeyres formula is generally used." name="description"/>
#   <meta content="" name="robots"/>
#   <link href="/assets/images/icons/FAVICON/macro-trends_favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="1228954C688F5907894001CD8E5E624B" name="msvalidate.01"/>
#   <meta content="6MnD_3iDtAP1ZyoGK1YMyVIVck4r5Ws80I9xD3ue4_A" name="google-site-verification"/>
#   <!-- Load in Roboto Font -->
#   <link href="https://fonts.googleapis.com/css?family=Roboto:400,600,700" rel="stylesheet"/>
#   <!-- Bootstrap -->
#   <link href="//maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" rel="stylesheet"/>
#   <!--for Bootstrap CDN version-->
#   <link href="//maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap-theme.min.css" rel="stylesheet"/>
#   <!-- Font Awesome -->
#   <link href="//stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet"/>
#   <!--for Font Awesome CDN version-->
#   <!-- Jquery, Bootstrap and Menu Javascript -->
#   <script crossorigin="anonymous" integrity="sha256-ZosEbRLbNQzLpnKIkEdrPv7lOy9C27hHQ+Xp8a4MxAQ=" src="//code.jquery.com/jquery-1.12.4.min.js">
#   </script>
#   <script src="//maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js">
#   </script>
#   <script language="javascript" src="/assets/javascript/jquery.iframetracker.js" type="text/javascript">
#   </script>
#   <!-- Sticky kit for sticky sidebar ad -->
#   <script language="javascript" src="/assets/javascript/jquery.sticky-kit.min.js" type="text/javascript">
#   </script>
#   <!-- Modernizr for cross-browser support -->
#   <script src="/assets/javascript/modernizr-2.6.2-respond-1.1.0.min.js" type="text/javascript">
#   </script>
#   <!-- Latest compiled and minified CSS -->
#   <link href="//www.fuelcdn.com/fuelux/3.13.0/css/fuelux.min.css" rel="stylesheet"/>
#   <!-- Latest compiled and minified JavaScript -->
#   <script src="//www.fuelcdn.com/fuelux/3.13.0/js/fuelux.min.js">
#   </script>
#   <!-- Twitter Card data -->
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@tmacrotrends" name="twitter:site"/>
#   <meta content="India Inflation Rate 1960-2020" name="twitter:title"/>
#   <meta content="Inflation as measured by the consumer price index reflects the annual percentage change in the cost to the average consumer of acquiring a basket of goods and services that may be fixed or changed at specified intervals, such as yearly. The Laspeyres formula is generally used." name="twitter:description"/>
#   <!-- Open Graph data -->
#   <meta content="https://www.macrotrends.net/countries/IND/india/inflation-rate-cpi" property="og:url"/>
#   <meta content="India Inflation Rate 1960-2020" property="og:title"/>
#   <meta content="Inflation as measured by the consumer price index reflects the annual percentage change in the cost to the average consumer of acquiring a basket of goods and services that may be fixed or changed at specified intervals, such as yearly. The Laspeyres formula is generally used." property="og:description"/>
#   <!-- JQXGRID STYLES AND JAVASCRIPT -->
#   <link href="/assets/php/jqfiles/jqwidgets/styles/jqx.base.css" rel="stylesheet" type="text/css"/>
#   <link href="/assets/php/jqfiles/jqwidgets/styles/jqx.bootstrap.css" rel="stylesheet" type="text/css"/>
#   <!-- LOAD THESE SCRIPTS EARLY SO THE TICKER INPUT FIELD IS STYLED INSTANTLY -->
#   <script src="/assets/php/jqfiles/jqwidgets/jqxcore.js" type="text/javascript">
#   </script>
#   <script src="/assets/php/jqfiles/jqwidgets/jqxdata.js" type="text/javascript">
#   </script>
#   <script src="/assets/php/jqfiles/jqwidgets/jqxinput.js" type="text/javascript">
#   </script>
#   <!-- Styling for search box -->
#   <link href="/assets/php/jquery-typeahead/jquery.typeahead_pages.css" rel="stylesheet" type="text/css"/>
#   <!-- Search box javascript -->
#   <script src="/assets/php/jquery-typeahead/jquery.typeahead.min.js">
#   </script>
#   <link href="//cdnjs.cloudflare.com/ajax/libs/select2/4.0.3/css/select2.min.css" rel="stylesheet"/>
#   <script src="//cdnjs.cloudflare.com/ajax/libs/select2/4.0.3/js/select2.min.js">
#   </script>
#   <!-- ToolTips -->
#   <script src="/assets/php/tipped-4.6.1/js/tipped/tipped.js">
#   </script>
#   <link href="/assets/php/tipped-4.6.1/css/tipped/tipped.css" rel="stylesheet"/>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-62099500-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
# 		  function gtag(){dataLayer.push(arguments);}
# 		  gtag('js', new Date());
#
# 		  gtag('config', 'UA-62099500-1');
#   </script>
#   <!-- Amcharts Files -->
#   <script src="/assets/php/charts/amcharts/amcharts.js" type="text/javascript">
#   </script>
#   <script src="/assets/php/charts/amcharts/serial.js" type="text/javascript">
#   </script>
#   <script src="/assets/php/charts/amcharts/themes/light.js" type="text/javascript">
#   </script>
#   <script src="/assets/php/charts/amcharts/amstock.js" type="text/javascript">
#   </script>
#   <script src="/assets/php/charts/amcharts/plugins/export/export.min.js?version=1527102356" type="text/javascript">
#   </script>
#   <script src="/assets/php/charts/amcharts/plugins/export/libs/fabric.js/fabric.min.js?version=1510086154" type="text/javascript">
#   </script>
#   <script src="/assets/php/charts/amcharts/plugins/export/libs/FileSaver.js/FileSaver.js?version=1500654620" type="text/javascript">
#   </script>
#   <link href="/assets/php/charts/amcharts/plugins/export/export.css" media="all" rel="stylesheet" type="text/css"/>
#   <!-- Load in Macrotrends style sheet -->
#   <link href="/assets/css/macrotrends_main.css" rel="stylesheet"/>
#   <!--for Font Awesome CDN version-->
#   <!-- START IC AD INSERT -->
#   <script>
#    InvestingChannelQueue = window.InvestingChannelQueue || [];
#   </script>
#   <script async="" src="https://u5.investingchannel.com/static/uat.js">
#   </script>
#   <script type="text/javascript">
#    //Push Run command with the API-Key, so that UAT will start processing publishers request.
#         InvestingChannelQueue.push(function() {
#             page = InvestingChannel.UAT.Run("df17ac1e-cc7f-11e8-82a5-0abbb61c4a6a");
#         });
#
#         var oopDivTag;
# 		var subLeaderboardTag;
# 		var rightSidebarTag1;
# 		var rightSidebarTag2;
#
#         //To define new tags/out of page tags.
#         InvestingChannelQueue.push(function() {
#             oopDivTag = page.defineOutOfPageTag("Macrotrends/economics_charts","oopDivTag");
#             subLeaderboardTag = page.defineTag("Macrotrends/economics_charts","728x90","subLeaderboardTag");
# 			rightSidebarTag1 = page.defineTag("Macrotrends/economics_charts","300x250","ic_300_250");
# 			rightSidebarTag2 = page.defineTag("Macrotrends/economics_charts","300x600,300x250,160x600","ic_300_600");
#
#         });
#
#         //To render tags.
#         InvestingChannelQueue.push(function() {
#             page.renderTags();
#         });
#   </script>
#   <!-- END IC AD INSERT -->
#  </head>
#  <body class="fuelux">
#   <!--[if lt IE 7]>
#             <p class="browsehappy">You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> to improve your experience.</p>
#         <![endif]-->
#   <div class="header_content_container container-fluid">
#    <div class="header_parent_container">
#     <div class="header_container">
#      <div class="header_logo col-xs-2">
#       <a class="logo" href="http://www.macrotrends.net" title="MacroTrends Home Page">
#        <img src="/assets/images/logo_bright1.png"/>
#       </a>
#      </div>
#      <div class="col-xs-5 pull-right" style="padding-top:8px;">
#       <form>
#        <div class="typeahead__container">
#         <div class="typeahead__field">
#          <span class="typeahead__query">
#           <input autocomplete="off" autofocus="" class="js-typeahead" name="q" placeholder="Search over 200,000 charts..." type="search"/>
#          </span>
#          <span class="typeahead__button">
#           <button type="submit">
#            <span class="typeahead__search-icon">
#            </span>
#           </button>
#          </span>
#         </div>
#        </div>
#       </form>
#      </div>
#     </div>
#    </div>
#    <div class="menu_parent_container">
#     <div class="menu_container">
#      <div class="dropdown">
#       <button class="dropbtn">
#        Markets
#       </button>
#       <div class="dropdown-content">
#        <a href="/charts/stock-indexes">
#         <div class="menu_item">
#          Market Indexes
#         </div>
#        </a>
#        <a href="/charts/precious-metals">
#         <div class="menu_item">
#          Precious Metals
#         </div>
#        </a>
#        <a href="/charts/energy">
#         <div class="menu_item">
#          Energy
#         </div>
#        </a>
#        <a href="/charts/commodities">
#         <div class="menu_item">
#          Commodities
#         </div>
#        </a>
#        <a href="/charts/exchange-rates">
#         <div class="menu_item">
#          Exchange Rates
#         </div>
#        </a>
#        <a href="/charts/interest-rates">
#         <div class="menu_item">
#          Interest Rates
#         </div>
#        </a>
#        <a href="/futures">
#         <div class="menu_item">
#          Futures
#         </div>
#        </a>
#       </div>
#      </div>
#      <div class="dropdown">
#       <button class="dropbtn">
#        Stock Research
#       </button>
#       <div class="dropdown-content">
#        <a href="/stocks/research">
#         <div class="menu_item">
#          Top Stocks
#         </div>
#        </a>
#        <a href="/stocks/stock-screener">
#         <div class="menu_item">
#          Stock Screener
#         </div>
#        </a>
#        <a href="/stocks/high-dividend/top-100-high-dividend-yield-stocks">
#         <div class="menu_item">
#          Top 100 Dividend Stocks
#         </div>
#        </a>
#       </div>
#      </div>
#      <div class="dropdown">
#       <button class="dropbtn">
#        Economy
#       </button>
#       <div class="dropdown-content">
#        <a href="/charts/economy">
#         <div class="menu_item">
#          U.S. Economic Charts
#         </div>
#        </a>
#        <a href="/countries/ranking/gdp-gross-domestic-product">
#         GDP by Country
#        </a>
#        <a href="/countries/ranking/gdp-per-capita">
#         GDP Per Capita by Country
#        </a>
#        <a href="/countries/ranking/manufacturing-output">
#         Manufacturing by Country
#        </a>
#        <a href="/countries/ranking/debt-to-gdp-ratio">
#         Debt to GDP Ratio by Country
#        </a>
#       </div>
#      </div>
#      <div class="dropdown">
#       <button class="dropbtn">
#        Global Metrics
#       </button>
#       <div class="dropdown-content">
#        <a href="/countries/topic-overview">
#         Topic Overview
#        </a>
#        <a href="/countries/ranking/population">
#         Largest Countries by Population
#        </a>
#        <a href="/states/us-states-by-population">
#         U.S. States by Population
#        </a>
#        <a href="/cities/largest-cities-by-population">
#         U.S. and World Cities by Population
#        </a>
#       </div>
#      </div>
#      <div class="dropdown">
#       <button class="dropbtn">
#        Tools
#       </button>
#       <div class="dropdown-content">
#        <a href="/tools/calculators/401k-retirement-calculator">
#         <div class="menu_item">
#          401K Calculator
#         </div>
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="main_content_container container-fluid" id="main_content_container">
#    <div class="col-xs-12" id="leaderboardTag" style="margin: 20px 0px 30px 0px; padding:0px; min-height:265px; text-align:center;">
#    </div>
#    <div style="margin:40px 15px 20px 15px;">
#     <h1 style="font-weight:600; color:#444;">
#      India Inflation Rate 1960-2020
#     </h1>
#    </div>
#    <div id="main_content">
#     <div class="navigation_tabs" style="margin-bottom:20px;">
#      <ul class="nav nav-tabs" id="myTabs" style="font-size:15px;">
#       <li>
#        <a href="https://www.macrotrends.net/countries/IND/india/population">
#         Population
#        </a>
#       </li>
#       <li class="active">
#        <a href="https://www.macrotrends.net/countries/IND/india/gdp-gross-domestic-product">
#         Economy
#        </a>
#       </li>
#       <li>
#        <a href="https://www.macrotrends.net/countries/IND/india/trade-balance-deficit">
#         Trade
#        </a>
#       </li>
#       <li>
#        <a href="https://www.macrotrends.net/countries/IND/india/healthcare-spending">
#         Health
#        </a>
#       </li>
#       <li>
#        <a href="https://www.macrotrends.net/countries/IND/india/literacy-rate">
#         Education
#        </a>
#       </li>
#       <li>
#        <a href="https://www.macrotrends.net/countries/IND/india/poverty-rate">
#         Development
#        </a>
#       </li>
#       <li>
#        <a href="https://www.macrotrends.net/countries/IND/india/unemployment-rate">
#         Labor Force
#        </a>
#       </li>
#       <li>
#        <a href="https://www.macrotrends.net/countries/IND/india/carbon-co2-emissions">
#         Environment
#        </a>
#       </li>
#       <li>
#        <a href="https://www.macrotrends.net/countries/IND/india/crime-rate-statistics">
#         Crime
#        </a>
#       </li>
#       <li>
#        <a href="https://www.macrotrends.net/countries/IND/india/immigration-statistics">
#         Immigration
#        </a>
#       </li>
#       <li>
#        <a href="https://www.macrotrends.net/countries/IND/india/military-spending-defense-budget">
#         Other
#        </a>
#       </li>
#      </ul>
#      <ul class="nav nav-tabs" id="myTabs" style="font-size:15px;">
#       <li>
#        <a href="https://www.macrotrends.net/countries/IND/india/gdp-gross-domestic-product">
#         GDP
#        </a>
#       </li>
#       <li>
#        <a href="https://www.macrotrends.net/countries/IND/india/gdp-growth-rate">
#         GDP Growth Rate
#        </a>
#       </li>
#       <li>
#        <a href="https://www.macrotrends.net/countries/IND/india/gdp-per-capita">
#         GDP Per Capita
#        </a>
#       </li>
#       <li>
#        <a href="https://www.macrotrends.net/countries/IND/india/gni-gross-national-income">
#         GNI
#        </a>
#       </li>
#       <li>
#        <a href="https://www.macrotrends.net/countries/IND/india/gni-per-capita">
#         GNI Per Capita
#        </a>
#       </li>
#       <li>
#        <a href="https://www.macrotrends.net/countries/IND/india/debt-to-gdp-ratio">
#         Debt to GDP
#        </a>
#       </li>
#       <li>
#        <a href="https://www.macrotrends.net/countries/IND/india/gnp-gross-national-product">
#         GNP
#        </a>
#       </li>
#       <li class="active">
#        <a href="https://www.macrotrends.net/countries/IND/india/inflation-rate-cpi">
#         Inflation Rate
#        </a>
#       </li>
#       <li>
#        <a href="https://www.macrotrends.net/countries/IND/india/economic-growth-rate">
#         Economic Growth
#        </a>
#       </li>
#       <li>
#        <a href="https://www.macrotrends.net/countries/IND/india/manufacturing-output">
#         Manufacturing
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div style="background-color:#fff; margin: 0px 0px 20px 0px; padding:20px 30px; border:1px solid #dfdfdf;">
#      <span style="color:#444; line-height: 1.8;">
#       Inflation as measured by the consumer price index reflects the annual percentage change in the cost to the average consumer of acquiring a basket of goods and services that may be fixed or changed at specified intervals, such as yearly. The Laspeyres formula is generally used.
#       <ul style="margin-top:10px;">
#        <li>
#         India inflation rate for 2019 was
#         <strong>
#          7.66%
#         </strong>
#         , a
#         <strong>
#          2.8% increase
#         </strong>
#         from 2018.
#        </li>
#        <li>
#         India inflation rate for 2018 was
#         <strong>
#          4.86%
#         </strong>
#         , a
#         <strong>
#          2.37% increase
#         </strong>
#         from 2017.
#        </li>
#        <li>
#         India inflation rate for 2017 was
#         <strong>
#          2.49%
#         </strong>
#         , a
#         <strong>
#          2.45% decline
#         </strong>
#         from 2016.
#        </li>
#        <li>
#         India inflation rate for 2016 was
#         <strong>
#          4.94%
#         </strong>
#         , a
#         <strong>
#          0.93% decline
#         </strong>
#         from 2015.
#        </li>
#       </ul>
#      </span>
#     </div>
#     <div style="background-color:#fff; margin: 30px 0px 30px 0px; text-align:center; min-height:90px;">
#      <div id="subLeaderboardTag" style="margin:10px 20px; min-height:90px;">
#      </div>
#     </div>
#     <div class="ticker_search_box" style="text-align:center; height:56px;">
#      <div class="col-xs-7">
#       <script type="text/javascript">
#        $(document).ready(function () {
#
# 					var url = "https://www.macrotrends.net/assets/php/global_metrics/country_search_list.php";
#
#                 // prepare the data
#                 var source =
#                 {
#                     datatype: "json",
#                     datafields: [
#                         { name: 'n' },
# 						{ name: 's'}
#                     ],
#                     url: url
#                 };
#                 var dataAdapter = new $.jqx.dataAdapter(source);
#                 // Create a jqxInput
#                 $("#jqxInput").jqxInput({ source: dataAdapter, minLength: 1, placeHolder: "Search over 200 countries...", items: 20, searchMode: 'containsignorecase', displayMember: "n", valueMember: "s", width: '100%', height: 22, theme: 'bootstrap'});
#                 $("#jqxInput").on('select', function (event) {
#                     if (event.args) {
#                         var item = event.args.item;
#
# 						//Have to split the ticker and slug back out since jqxinput only seems to allow one data value
# 						var itemArray = item.value.split("\/");
# 						var country_name = itemArray[0];
# 						var country_id = itemArray[1];
#                         if (item) {
#
# 								window.location = "https://www.macrotrends.net/countries/" + country_id + "/" + country_name + "/inflation-rate-cpi";
#
#
#                         }
#                     }
#                 });
#             });
#       </script>
#       <input id="jqxInput"/>
#      </div>
#      <div class="col-xs-5">
#       <button class="chart_buttons btn btn-danger btn-xs" id="dataDownload">
#        <span class="glyphicon glyphicon-cloud-download">
#        </span>
#        <strong>
#         Download Historical Data
#        </strong>
#       </button>
#       <button class="chart_buttons btn btn-success btn-xs" data-target="#smallWidthModal" data-toggle="modal" id="chartExport">
#        <span class="glyphicon glyphicon-picture">
#        </span>
#        <strong>
#         Save as Image
#        </strong>
#       </button>
#      </div>
#     </div>
#     <div style="height:670px; background-color:#fff; border:1px solid #dfdfdf;">
#      <div id="chartdiv" style="width:100%; height:615px; background_color:#fff; padding:30px">
#      </div>
#     </div>
#     <div style="background-color:#fff; margin: 30px 0px 0px 0px; padding:20px 30px; border:1px solid #dfdfdf;">
#      <span>
#       Data Source:
#      </span>
#      <a href="http://datatopics.worldbank.org/world-development-indicators/">
#       World Bank
#      </a>
#      <br/>
#      <br/>
#      <span>
#       MLA Citation:
#       <span>
#        <input class="modal_link" size="80" type="text" value="&lt;a href='https://www.macrotrends.net/countries/IND/india/inflation-rate-cpi'&gt;India Inflation Rate 1960-2020&lt;/a&gt;. www.macrotrends.net. Retrieved 2020-11-18."/>
#       </span>
#      </span>
#     </div>
#     <div id="dianomi_800_300" style="background-color:#fff; margin: 30px 0px 0px 0px; padding:20px 30px 10px 30px; border:1px solid #dfdfdf;">
#     </div>
#     <div class="col-xs-5" style="background-color:#fff; margin: 30px 0px 30px 0px; padding:0px 0px 0px 0px;">
#      <table class="historical_data_table table table-striped table-bordered">
#       <thead>
#        <tr>
#         <th colspan="2" style="text-align:center;">
#          Similar Country Ranking
#         </th>
#        </tr>
#       </thead>
#       <thead>
#        <tr>
#         <th style="text-align:center;">
#          Country Name
#         </th>
#         <th style="text-align:center;">
#          Inflation Rate (%)
#         </th>
#        </tr>
#       </thead>
#       <tbody>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/SDN/sudan/inflation-rate-cpi">
#           Sudan
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          50.99%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/AGO/angola/inflation-rate-cpi">
#           Angola
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          17.15%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/NGA/nigeria/inflation-rate-cpi">
#           Nigeria
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          11.40%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/PAK/pakistan/inflation-rate-cpi">
#           Pakistan
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          10.58%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/ZMB/zambia/inflation-rate-cpi">
#           Zambia
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          9.15%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/MMR/myanmar/inflation-rate-cpi">
#           Myanmar
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          8.83%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/UKR/ukraine/inflation-rate-cpi">
#           Ukraine
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          7.89%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; font-size:20px; font-weight:bold;">
#          <a href="/countries/IND/india/inflation-rate-cpi">
#           India
#          </a>
#         </td>
#         <td style="text-align:center; font-size:20px; font-weight:bold;">
#          7.66%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/MNG/mongolia/inflation-rate-cpi">
#           Mongolia
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          7.30%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/GHA/ghana/inflation-rate-cpi">
#           Ghana
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          7.18%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/TUN/tunisia/inflation-rate-cpi">
#           Tunisia
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          6.72%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/BGD/bangladesh/inflation-rate-cpi">
#           Bangladesh
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          5.59%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/NIC/nicaragua/inflation-rate-cpi">
#           Nicaragua
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          5.38%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/LSO/lesotho/inflation-rate-cpi">
#           Lesotho
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          5.19%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/GEO/georgia/inflation-rate-cpi">
#           Georgia
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          4.85%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/MDA/moldova/inflation-rate-cpi">
#           Moldova
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          4.84%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/HND/honduras/inflation-rate-cpi">
#           Honduras
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          4.37%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/PNG/papua-new-guinea/inflation-rate-cpi">
#           Papua New Guinea
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          3.64%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/LKA/sri-lanka/inflation-rate-cpi">
#           Sri Lanka
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          3.53%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/LAO/lao-pdr/inflation-rate-cpi">
#           Lao PDR
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          3.32%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/DJI/djibouti/inflation-rate-cpi">
#           Djibouti
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          3.32%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/IDN/indonesia/inflation-rate-cpi">
#           Indonesia
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          3.03%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/VNM/vietnam/inflation-rate-cpi">
#           Vietnam
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          2.80%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/VUT/vanuatu/inflation-rate-cpi">
#           Vanuatu
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          2.76%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/BTN/bhutan/inflation-rate-cpi">
#           Bhutan
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          2.73%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/XKX/kosovo/inflation-rate-cpi">
#           Kosovo
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          2.68%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/PHL/philippines/inflation-rate-cpi">
#           Philippines
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          2.48%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/CMR/cameroon/inflation-rate-cpi">
#           Cameroon
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          2.45%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/MRT/mauritania/inflation-rate-cpi">
#           Mauritania
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          2.30%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/COG/congo-rep/inflation-rate-cpi">
#           Congo, Rep.
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          2.21%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/BOL/bolivia/inflation-rate-cpi">
#           Bolivia
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          1.84%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/SLB/solomon-islands/inflation-rate-cpi">
#           Solomon Islands
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          1.63%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/PSE/west-bank-and-gaza/inflation-rate-cpi">
#           West Bank and Gaza
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          1.58%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/KGZ/kyrgyz-republic/inflation-rate-cpi">
#           Kyrgyz Republic
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          1.13%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/CPV/cabo-verde/inflation-rate-cpi">
#           Cabo Verde
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          1.11%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/MAR/morocco/inflation-rate-cpi">
#           Morocco
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          0.20%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:left; ">
#          <a href="/countries/SLV/el-salvador/inflation-rate-cpi">
#           El Salvador
#          </a>
#         </td>
#         <td style="text-align:center; ">
#          0.08%
#         </td>
#        </tr>
#       </tbody>
#      </table>
#     </div>
#     <div class="col-xs-1">
#     </div>
#     <div class="col-xs-6" style="background-color:#fff; margin: 30px 0px 30px 0px; padding:0px 30px 0px 0px;">
#      <table class="historical_data_table table table-striped table-bordered">
#       <thead>
#        <tr>
#         <th colspan="3" style="text-align:center;">
#          India Inflation Rate - Historical Data
#         </th>
#        </tr>
#       </thead>
#       <thead>
#        <tr>
#         <th style="text-align:center;">
#          Year
#         </th>
#         <th style="text-align:center;">
#          Inflation Rate (%)
#         </th>
#         <th style="text-align:center;">
#          Annual Change
#         </th>
#        </tr>
#       </thead>
#       <tbody>
#        <tr>
#         <td style="text-align:center">
#          2019
#         </td>
#         <td style="text-align:center;">
#          7.66%
#         </td>
#         <td style="text-align:center;">
#          2.80%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          2018
#         </td>
#         <td style="text-align:center;">
#          4.86%
#         </td>
#         <td style="text-align:center;">
#          2.37%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          2017
#         </td>
#         <td style="text-align:center;">
#          2.49%
#         </td>
#         <td style="text-align:center;">
#          -2.45%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          2016
#         </td>
#         <td style="text-align:center;">
#          4.94%
#         </td>
#         <td style="text-align:center;">
#          -0.93%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          2015
#         </td>
#         <td style="text-align:center;">
#          5.87%
#         </td>
#         <td style="text-align:center;">
#          -0.48%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          2014
#         </td>
#         <td style="text-align:center;">
#          6.35%
#         </td>
#         <td style="text-align:center;">
#          -4.55%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          2013
#         </td>
#         <td style="text-align:center;">
#          10.91%
#         </td>
#         <td style="text-align:center;">
#          1.60%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          2012
#         </td>
#         <td style="text-align:center;">
#          9.31%
#         </td>
#         <td style="text-align:center;">
#          0.45%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          2011
#         </td>
#         <td style="text-align:center;">
#          8.86%
#         </td>
#         <td style="text-align:center;">
#          -3.13%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          2010
#         </td>
#         <td style="text-align:center;">
#          11.99%
#         </td>
#         <td style="text-align:center;">
#          1.11%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          2009
#         </td>
#         <td style="text-align:center;">
#          10.88%
#         </td>
#         <td style="text-align:center;">
#          2.53%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          2008
#         </td>
#         <td style="text-align:center;">
#          8.35%
#         </td>
#         <td style="text-align:center;">
#          1.98%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          2007
#         </td>
#         <td style="text-align:center;">
#          6.37%
#         </td>
#         <td style="text-align:center;">
#          0.58%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          2006
#         </td>
#         <td style="text-align:center;">
#          5.80%
#         </td>
#         <td style="text-align:center;">
#          1.55%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          2005
#         </td>
#         <td style="text-align:center;">
#          4.25%
#         </td>
#         <td style="text-align:center;">
#          0.48%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          2004
#         </td>
#         <td style="text-align:center;">
#          3.77%
#         </td>
#         <td style="text-align:center;">
#          -0.04%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          2003
#         </td>
#         <td style="text-align:center;">
#          3.81%
#         </td>
#         <td style="text-align:center;">
#          -0.49%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          2002
#         </td>
#         <td style="text-align:center;">
#          4.30%
#         </td>
#         <td style="text-align:center;">
#          0.52%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          2001
#         </td>
#         <td style="text-align:center;">
#          3.78%
#         </td>
#         <td style="text-align:center;">
#          -0.23%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          2000
#         </td>
#         <td style="text-align:center;">
#          4.01%
#         </td>
#         <td style="text-align:center;">
#          -0.66%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1999
#         </td>
#         <td style="text-align:center;">
#          4.67%
#         </td>
#         <td style="text-align:center;">
#          -8.56%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1998
#         </td>
#         <td style="text-align:center;">
#          13.23%
#         </td>
#         <td style="text-align:center;">
#          6.07%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1997
#         </td>
#         <td style="text-align:center;">
#          7.16%
#         </td>
#         <td style="text-align:center;">
#          -1.81%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1996
#         </td>
#         <td style="text-align:center;">
#          8.98%
#         </td>
#         <td style="text-align:center;">
#          -1.25%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1995
#         </td>
#         <td style="text-align:center;">
#          10.22%
#         </td>
#         <td style="text-align:center;">
#          -0.02%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1994
#         </td>
#         <td style="text-align:center;">
#          10.25%
#         </td>
#         <td style="text-align:center;">
#          3.92%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1993
#         </td>
#         <td style="text-align:center;">
#          6.33%
#         </td>
#         <td style="text-align:center;">
#          -5.46%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1992
#         </td>
#         <td style="text-align:center;">
#          11.79%
#         </td>
#         <td style="text-align:center;">
#          -2.08%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1991
#         </td>
#         <td style="text-align:center;">
#          13.87%
#         </td>
#         <td style="text-align:center;">
#          4.90%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1990
#         </td>
#         <td style="text-align:center;">
#          8.97%
#         </td>
#         <td style="text-align:center;">
#          1.90%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1989
#         </td>
#         <td style="text-align:center;">
#          7.07%
#         </td>
#         <td style="text-align:center;">
#          -2.31%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1988
#         </td>
#         <td style="text-align:center;">
#          9.38%
#         </td>
#         <td style="text-align:center;">
#          0.58%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1987
#         </td>
#         <td style="text-align:center;">
#          8.80%
#         </td>
#         <td style="text-align:center;">
#          0.07%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1986
#         </td>
#         <td style="text-align:center;">
#          8.73%
#         </td>
#         <td style="text-align:center;">
#          3.17%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1985
#         </td>
#         <td style="text-align:center;">
#          5.56%
#         </td>
#         <td style="text-align:center;">
#          -2.76%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1984
#         </td>
#         <td style="text-align:center;">
#          8.32%
#         </td>
#         <td style="text-align:center;">
#          -3.55%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1983
#         </td>
#         <td style="text-align:center;">
#          11.87%
#         </td>
#         <td style="text-align:center;">
#          3.98%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1982
#         </td>
#         <td style="text-align:center;">
#          7.89%
#         </td>
#         <td style="text-align:center;">
#          -5.22%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1981
#         </td>
#         <td style="text-align:center;">
#          13.11%
#         </td>
#         <td style="text-align:center;">
#          1.77%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1980
#         </td>
#         <td style="text-align:center;">
#          11.35%
#         </td>
#         <td style="text-align:center;">
#          5.07%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1979
#         </td>
#         <td style="text-align:center;">
#          6.28%
#         </td>
#         <td style="text-align:center;">
#          3.75%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1978
#         </td>
#         <td style="text-align:center;">
#          2.52%
#         </td>
#         <td style="text-align:center;">
#          -5.78%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1977
#         </td>
#         <td style="text-align:center;">
#          8.31%
#         </td>
#         <td style="text-align:center;">
#          15.94%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1976
#         </td>
#         <td style="text-align:center;">
#          -7.63%
#         </td>
#         <td style="text-align:center;">
#          -13.38%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1975
#         </td>
#         <td style="text-align:center;">
#          5.75%
#         </td>
#         <td style="text-align:center;">
#          -22.85%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1974
#         </td>
#         <td style="text-align:center;">
#          28.60%
#         </td>
#         <td style="text-align:center;">
#          11.66%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1973
#         </td>
#         <td style="text-align:center;">
#          16.94%
#         </td>
#         <td style="text-align:center;">
#          10.50%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1972
#         </td>
#         <td style="text-align:center;">
#          6.44%
#         </td>
#         <td style="text-align:center;">
#          3.36%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1971
#         </td>
#         <td style="text-align:center;">
#          3.08%
#         </td>
#         <td style="text-align:center;">
#          -2.01%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1970
#         </td>
#         <td style="text-align:center;">
#          5.09%
#         </td>
#         <td style="text-align:center;">
#          5.68%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1969
#         </td>
#         <td style="text-align:center;">
#          -0.58%
#         </td>
#         <td style="text-align:center;">
#          -3.82%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1968
#         </td>
#         <td style="text-align:center;">
#          3.24%
#         </td>
#         <td style="text-align:center;">
#          -9.82%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1967
#         </td>
#         <td style="text-align:center;">
#          13.06%
#         </td>
#         <td style="text-align:center;">
#          2.26%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1966
#         </td>
#         <td style="text-align:center;">
#          10.80%
#         </td>
#         <td style="text-align:center;">
#          1.33%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1965
#         </td>
#         <td style="text-align:center;">
#          9.47%
#         </td>
#         <td style="text-align:center;">
#          -3.88%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1964
#         </td>
#         <td style="text-align:center;">
#          13.36%
#         </td>
#         <td style="text-align:center;">
#          10.41%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1963
#         </td>
#         <td style="text-align:center;">
#          2.95%
#         </td>
#         <td style="text-align:center;">
#          -0.69%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1962
#         </td>
#         <td style="text-align:center;">
#          3.63%
#         </td>
#         <td style="text-align:center;">
#          1.94%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1961
#         </td>
#         <td style="text-align:center;">
#          1.70%
#         </td>
#         <td style="text-align:center;">
#          -0.08%
#         </td>
#        </tr>
#        <tr>
#         <td style="text-align:center">
#          1960
#         </td>
#         <td style="text-align:center;">
#          1.78%
#         </td>
#         <td style="text-align:center;">
#          -0.08%
#         </td>
#        </tr>
#       </tbody>
#      </table>
#     </div>
#    </div>
#    <div id="right_sidebar">
#     <div style="margin-top:0px; min-height:250px;">
#      <div id="ic_300_250">
#      </div>
#     </div>
#     <div id="sticky_ad_right">
#      <div style="margin-top:30px; min-height:250px;">
#       <div id="ic_300_600">
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!--This is the div for the IC OOP ad-->
#   <div id="oopDivTag" style="width:1px;height:1px;">
#   </div>
#   <footer class="footer">
#    <span>
#     © 2010-2020 Macrotrends LLC
#    </span>
#    |
#    <a href="/terms">
#     Terms of Service
#    </a>
#    |
#    <a href="/privacy">
#     Privacy Policy
#    </a>
#    |
#    <a href="mailto:%69n%66o@%6Dac%72otrends%2En%65t">
#     Contact Us
#    </a>
#   </footer>
#   <div aria-hidden="true" aria-labelledby="exampleModalLabel" class="modal" id="smallWidthModal1" role="dialog" tabindex="-1">
#    <div class="modal-dialog modal-lg">
#     <div class="modal-content">
#      <div class="modal-body">
#       <div class="modal_title">
#        <h2>
#         <strong>
#          We Need Your Support!
#         </strong>
#        </h2>
#       </div>
#       <p>
#        Backlinks from other websites and blogs are the lifeblood of our site and are our primary source of new traffic.
#       </p>
#       <p>
#       </p>
#       <p>
#        If you use our chart images on your site or blog, we ask that you provide attribution via a link back to this page.  We have provided a few examples below that you can copy and paste to your site:
#       </p>
#       <br/>
#       <table class="table">
#        <thead>
#         <tr>
#          <th>
#           Link Preview
#          </th>
#          <th>
#           HTML Code (Click to Copy)
#          </th>
#         </tr>
#        </thead>
#        <tbody>
#         <tr>
#          <td>
#           <a>
#            India Inflation Rate 1960-2020
#           </a>
#          </td>
#          <td>
#           <input class="modal_link" size="50" type="text" value="&lt;a href='https://www.macrotrends.net/countries/IND/india/inflation-rate-cpi'&gt;India Inflation Rate 1960-2020&lt;/a&gt;"/>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a>
#            Macrotrends
#           </a>
#          </td>
#          <td>
#           <input class="modal_link" size="50" type="text" value="&lt;a href='https://www.macrotrends.net/countries/IND/india/inflation-rate-cpi'&gt;Macrotrends&lt;/a&gt;"/>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a>
#            Source
#           </a>
#          </td>
#          <td>
#           <input class="modal_link" size="50" type="text" value="&lt;a href='https://www.macrotrends.net/countries/IND/india/inflation-rate-cpi'&gt;Source&lt;/a&gt;"/>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <br/>
#       <p style="text-align:center">
#        Your image export is now complete.  Please check your download folder.
#       </p>
#      </div>
#      <div class="modal-footer">
#       <button class="btn btn-primary" data-dismiss="modal" type="button">
#        Close Window
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" aria-labelledby="exampleModalLabel" class="modal" id="smallWidthModal2" role="dialog" tabindex="-1">
#    <div class="modal-dialog modal-lg">
#     <div class="modal-content">
#      <div class="modal-body">
#       <div class="modal_title">
#        <h2>
#         <strong>
#          We Need Your Support!
#         </strong>
#        </h2>
#       </div>
#       <p>
#        Backlinks from other websites and blogs are the lifeblood of our site and are our primary source of new traffic.
#       </p>
#       <p>
#       </p>
#       <p>
#        If you use our datasets on your site or blog, we ask that you provide attribution via a link back to this page.  We have provided a few examples below that you can copy and paste to your site:
#       </p>
#       <br/>
#       <table class="table">
#        <thead>
#         <tr>
#          <th>
#           Link Preview
#          </th>
#          <th>
#           HTML Code (Click to Copy)
#          </th>
#         </tr>
#        </thead>
#        <tbody>
#         <tr>
#          <td>
#           <a>
#            India Inflation Rate 1960-2020
#           </a>
#          </td>
#          <td>
#           <input class="modal_link" size="50" type="text" value="&lt;a href='https://www.macrotrends.net/countries/IND/india/inflation-rate-cpi'&gt;India Inflation Rate 1960-2020&lt;/a&gt;"/>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a>
#            Macrotrends
#           </a>
#          </td>
#          <td>
#           <input class="modal_link" size="50" type="text" value="&lt;a href='https://www.macrotrends.net/countries/IND/india/inflation-rate-cpi'&gt;Macrotrends&lt;/a&gt;"/>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <a>
#            Source
#           </a>
#          </td>
#          <td>
#           <input class="modal_link" size="50" type="text" value="&lt;a href='https://www.macrotrends.net/countries/IND/india/inflation-rate-cpi'&gt;Source&lt;/a&gt;"/>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <br/>
#       <p style="text-align:center">
#        Your data export is now complete.  Please check your download folder.
#       </p>
#      </div>
#      <div class="modal-footer">
#       <button class="btn btn-primary" data-dismiss="modal" type="button">
#        Close Window
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   
# var chart = AmCharts.makeChart( "chartdiv", {
#   "type": "stock",
#   "dataDateFormat": "YYYY-MM-DD",
#   "precision": 0,
#   "export": {
# 		"enabled": true,
# 		"menu": [],
# 		"libs": {
# 			"autoLoad": false
# 		}
# 	},
#   "fontSize":14,
#   "theme": "light",
#   "dataSets": [ {
#     "fieldMappings": [{
#       "fromField": "v1",
#       "toField": "v1"
#     },{
#       "fromField": "v2",
#       "toField": "v2"
#     },{
#       "fromField": "v3",
#       "toField": "v3"
#     }],
#     "color": "#7f8da9",
#     "dataProvider": chartData,
#     "categoryField": "date"
#   } ],
#
# 	"allLabels": [
# 		{
# 			"text": "Free label",
# 			"bold": true,
# 			"color": "#000000",
# 			"size": 25,
# 			"x": 100,
# 			"y": 100
# 		}
# 	],
#
#   "panels": [ {
#       "showCategoryAxis": false,
#       "percentHeight": 60,
#       "valueAxes": [ {
#         "id": "v1",
#         "dashLength": 5,
# 	    "title": "Inflation Rate (%)",
# 	    "titleRotation":270,
# 	    "inside":false,
# 	    "logarithmic": false
#       } ],
#
#       "categoryAxis": {
#         "dashLength": 5,
# 		"parseDates": true,
# 		"equalSpacing": true
#       },
#
#       "stockGraphs": [
#
# 	{
#         "type": "line",
#         "id": "g1",
#  		"precision": 2,
#         "valueField": "v1",
#         "lineColor": "#5B9BD5",
# 		"useDataSetColors": false,
# 		"bullet":"round",
# 		"bulletSize": 10,
# 		"lineThickness": 3,
# 		"lineAlphas":1,
#         "fillAlphas": 0,
#         "showBalloon": true,
# 		"balloonText": "<table style=\"font-size:14px;\"><tr><td>[[value]]%</td></tr></table>",
#       }
#
# 	  ]
#     },{
#
#
#       "showCategoryAxis": true,
#
#
#       "percentHeight": 40,
#       "valueAxes": [ {
#         "id": "v1",
#         "dashLength": 5,
# 	    "title": "Annual Change",
# 	    "titleRotation":270,
# 	    "inside":false,
# 	    "logarithmic": false
#       } ],
#
#       "categoryAxis": {
#         "dashLength": 5,
# 		"parseDates": true,
# 		"equalSpacing": true
#       },
#
#       "stockGraphs": [ {
#
#
#         "type": "column",
#         "id": "g2",
#  		"precision": 2,
#         "valueField": "v2",
#         "fillColors": "#008000",
#         "lineColor": "#008000",
#         "negativeFillColors": "#FF0000",
#         "negativeLineColor": "#FF0000",
# 		"useDataSetColors": false,
# 		"lineAlphas":1,
#         "fillAlphas": 1,
#
#
#
#         "showBalloon": true,
# 		"balloonText": "<table style=\"font-size:14px;\"><tr><td>[[value]]%</td></tr></table>",
#       } ]
#     }
#
#
#   ],
#
# "panelsSettings": {
# 	"marginLeft": 30,
# 	"marginRight": 20,
# 	"marginTop": 10,
# 	"marginBottom":0,
# 	"startDuration": 0
# 	},
#
#   "categoryAxesSettings": {
# 	"minPeriod": "YYYY",
# 	"groupToPeriods": ['YYYY'],	"equalSpacing": true,
# 	"fontSize":14
#   },
#
#   "chartScrollbarSettings": {
#     "enabled": true,
# 	"graph": "g1",
#     "graphType": "line"
#   },
#
#     "chartCursorSettings": {
# 		"categoryBalloonDateFormats": [
# 		{period:'MM',format:'MM/YYYY'},
# 		{period:'YYYY',format:'YYYY'}],
# 		"bulletsEnabled": true,
# 		"bulletSize": 8,
#         "valueBalloonsEnabled": true,
# 		"fontSize": 14,
# 		"cursorColor": '#000000',
# 		"cursorAlpha": 0.34,
# 		"zoomable": true
#     },
#
# 	"balloon": {
# 		"fontSize": 14,
# 		"cornerRadius": 0,
# 		"borderThickness": 1,
# 		"fillAlpha": .94
# 	},
#
# 	"periodSelector": {
# 		"enabled": true,
# 		"periodsText": "Zoom: ",
# 		"position": "top",
# 		"fontSize": 14,
# 		"inputFieldsEnabled": true,
# 		"dateFormat": "YYYY",
# 		"fromText": "From: ",
# 		"toText": " To: ",
# 		"periods": [{
# 			"period": "YYYY",
# 			"count": 5,
# 			"label": " 5Y "
# 		}, {
# 			"period": "YYYY",
# 			"count": 10,
# 			"label": " 10Y "
# 		}, {
# 			"period": "YYYY",
# 			"count": 20,
# 			"label": " 20Y "
# 		}, {
# 			"period": "YYYY",
# 			"count": 30,
# 			"label": " 30Y "
# 		}, {
# 			"selected": true,
# 			"period": "MAX",
# 			"label": " All "
# 		}]
# 	},
#
# 	"listeners": [{
#     "event": "rendered",
#     "method": function(e) {
# 		$( "#leaderboardTag" ).append( "<iframe WIDTH='970' HEIGHT='250' SCROLLING='NO' src='https://www.dianomi.com/smartads.epl?id=4783'  style='width: 970px; height: 250px; border: none; overflow: hidden;'></iframe>" );
#
# 		$( "#dianomi_800_300" ).append( "<iframe WIDTH='800' HEIGHT='300' SCROLLING='NO' src='https://www.dianomi.com/smartads.epl?id=4784'  style='width: 100%; height: 300px; border: none; overflow: hidden;'></iframe>" );
#
#     }
#   },{
#     "event": "rendered",
#     "method": function(e) {
# 	  var panels = e.chart.panels;
#       setTimeout(function(){
#       panels.forEach(function(panel) {
#         panel.chartCursor.showCursorAt(new Date(2050, 12, 01));
#       })
#       }, 200)
#     }
#   }]
# } );
#
#
#
# document.getElementById("chartExport").onclick = function()
# 	{
#
# 		window.parent.$('#smallWidthModal1').modal();
#
# 		//Turn off scroll bar for image export
# 		chart.chartScrollbarSettings.enabled = false;
# 		chart.panelsSettings.marginLeft = 60;
# 		chart.panelsSettings.marginRight = 0;
# 		chart.panelsSettings.marginTop = 15;
# 		chart.panelsSettings.marginBottom = 15;
# 		chart.validateNow();
#
# 		chart.export.capture({},function() {
# 				this.toPNG({},function(data) {
# 					// Download the image to the browser
# 					this.download( data, "image/png", "india-inflation-rate-cpi-2020-11-18-macrotrends.png" );
#
# 					});
# 		//Turn scroll bar back on again
# 		chart.chartScrollbarSettings.enabled = true;
# 		chart.panelsSettings.marginLeft = 30;
# 		chart.panelsSettings.marginRight = 20;
# 		chart.panelsSettings.marginTop = 0;
# 		chart.panelsSettings.marginBottom = 0;
# 		chart.validateNow();
#
# 		});
#
# 	};
#
# document.getElementById("dataDownload").onclick = function()
# 	{
# 		//window.parent.ga('send', 'event', {
# 		//  'eventCategory': 'Downloads',
# 		//  'eventAction': 'DPD',
# 		//  'eventLabel': 'Export Data'
# 		//});
#
# 		window.parent.clicky.goal('2687', null );
# 		window.parent.clicky.pause( 500 );
#
# 		window.parent.$('#smallWidthModal2').modal();
#
# 		var csv = 'Macrotrends Data Download\r\n';
# 		csv += '\r\n';
# 		csv += 'India Inflation Rate 1960-2020\r\n';
# 		csv += '\r\n';
# 		csv += '\r\n';
# 		csv += 'DISCLAIMER AND TERMS OF USE: HISTORICAL DATA IS PROVIDED "AS IS" AND SOLELY\r\n';
# 		csv += 'FOR INFORMATIONAL PURPOSES - NOT FOR TRADING PURPOSES OR ADVICE.\r\n';
# 		csv += 'NEITHER MACROTRENDS LLC NOR ANY OF OUR INFORMATION PROVIDERS WILL BE LIABLE\r\n';
# 		csv += 'FOR ANY DAMAGES RELATING TO YOUR USE OF THE DATA PROVIDED.\r\n';
# 		csv += '\r\n';
# 		csv += '\r\n';
# 		csv += 'ATTRIBUTION: Proper attribution requires clear indication of the data source as "www.macrotrends.net".\r\n';
# 		csv += 'A "dofollow" backlink to the originating page is also required if the data is displayed on a web page.\r\n';
# 		csv += '\r\n';
# 		csv += '\r\n';
# 		csv += ', , , \r\n';
# 		csv += 'date, Inflation Rate (%), Annual Change, \r\n';
#
# 		for (var i = 0; i < chartData.length; i++) {
# 			var line = '';
# 			for (var index in chartData[i]) {
# 				if (line != '') line += ','
#
# 				if(index != "id") {
# 					line += chartData[i][index];
# 				}
# 			}
#
# 			csv += line + '\r\n';
# 		}
#
# 		//console.log(csv);
#
# 		var fileTitle = "india-inflation-rate-cpi";
#
#
# 		var exportedFilename = fileTitle + '.csv' || 'export.csv';
#
# 		var blob = new Blob([csv], { type: 'text/csv;charset=utf-8;' });
# 		if (navigator.msSaveBlob) { // IE 10+
# 			navigator.msSaveBlob(blob, exportedFilename);
# 		} else {
# 			var link = document.createElement("a");
# 			if (link.download !== undefined) { // feature detection
# 				// Browsers that support HTML5 download attribute
# 				var url = URL.createObjectURL(blob);
# 				link.setAttribute("href", url);
# 				link.setAttribute("download", exportedFilename);
# 				link.style.visibility = 'hidden';
# 				document.body.appendChild(link);
# 				link.click();
# 				document.body.removeChild(link);
# 			}
# 		}
#
# };
#
#
# 	$.typeahead({
# 		input: '.js-typeahead',
# 		minLength: 1,
# 		filter: false,  //Disables typahead filter to just show everything in the results from the database
# 		debug: false,
# 		highlight: true,
# 		maxItem: 10,
# 		dynamic: true,
# 		delay: 200,
# 		searchOnFocus: true,
# 		backdrop: {
# 			"background-color": "#fff"
# 		},
# 		href: "{{url}}",
# 		emptyTemplate: "no result for {{query}}",
# 		display: ["name"],
# 		source: {
# 			users: {
# 				ajax: {
# 					url: '/assets/php/all_pages_query.php',
# 					data: {
# 						q: '{{query}}'
# 					}
# 				}
# 			}
# 		}
# 	});
#   </script>
#   <script>
#    $(document).ready(function() {
#
# 	// Selects all of the text in the chart export window when clicked
# 	$(".modal_link").focus(function() {
# 		var $this = $(this);
# 		$this.select();
#
# 		// Work around Chrome's little problem
# 		$this.mouseup(function() {
# 			// Prevent further mouseup intervention
# 			$this.unbind("mouseup");
# 			return false;
# 		});
# 	});
#
# 	$('[data-toggle="tooltip"]').tooltip();
#
# });
#   </script>
#   <script type="text/javascript">
#    var clicky_site_ids = clicky_site_ids || [];
# clicky_site_ids.push(100827248);
# (function() {
#   var s = document.createElement('script');
#   s.type = 'text/javascript';
#   s.async = true;
#   s.src = '//static.getclicky.com/js';
#   ( document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0] ).appendChild( s );
# })();
#   </script>
#   <noscript>
#    <p>
#     <img alt="Clicky" height="1" src="//in.getclicky.com/100827248ns.gif" width="1"/>
#    </p>
#   </noscript>
#   <!-- Quantcast Tag -->
#   <script type="text/javascript">
#    var _qevents = _qevents || [];
#
# (function() {
# var elem = document.createElement('script');
# elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
# elem.async = true;
# elem.type = "text/javascript";
# var scpt = document.getElementsByTagName('script')[0];
# scpt.parentNode.insertBefore(elem, scpt);
# })();
#
# _qevents.push({
# qacct:"p-6yPRmhtTYyEtQ"
# });
#   </script>
#   <noscript>
#    <div style="display:none;">
#     <img alt="Quantcast" border="0" height="1" src="//pixel.quantserve.com/pixel/p-6yPRmhtTYyEtQ.gif" width="1"/>
#    </div>
#   </noscript>
#   <!-- End Quantcast tag -->
#  </body>
# </html>

# %%
# URL Title

print(soup.title.text)
# Out:
# India Inflation Rate 1960-2020 | MacroTrends

# %%
# Extracting Title & Header from the URL

inflation_table = soup.find("div", attrs={"class": "col-xs-6"})
inflation_table_data = inflation_table.table.find_all('thead')

tl = inflation_table_data[0].text.lstrip()
hr = inflation_table_data[1].text.lstrip()

print(tl) # title
print(hr) # header
# Out:
# India Inflation Rate - Historical Data
#
#
# Year
# Inflation Rate (%)
# Annual Change

# %%
# Extrating Column Values from URL

inflation_table = soup.find("div", attrs={"class": "col-xs-6"})
inflation_table_data = inflation_table.tbody.find_all("tr")

col_values = []
for i in range(len(inflation_table_data)):
  col_values.append(inflation_table_data[i].text.lstrip())

print(col_values)
# Out:
# ['2019\n7.66%\n2.80%\n', '2018\n4.86%\n2.37%\n', '2017\n2.49%\n-2.45%\n', '2016\n4.94%\n-0.93%\n', '2015\n5.87%\n-0.48%\n', '2014\n6.35%\n-4.55%\n', '2013\n10.91%\n1.60%\n', '2012\n9.31%\n0.45%\n', '2011\n8.86%\n-3.13%\n', '2010\n11.99%\n1.11%\n', '2009\n10.88%\n2.53%\n', '2008\n8.35%\n1.98%\n', '2007\n6.37%\n0.58%\n', '2006\n5.80%\n1.55%\n', '2005\n4.25%\n0.48%\n', '2004\n3.77%\n-0.04%\n', '2003\n3.81%\n-0.49%\n', '2002\n4.30%\n0.52%\n', '2001\n3.78%\n-0.23%\n', '2000\n4.01%\n-0.66%\n', '1999\n4.67%\n-8.56%\n', '1998\n13.23%\n6.07%\n', '1997\n7.16%\n-1.81%\n', '1996\n8.98%\n-1.25%\n', '1995\n10.22%\n-0.02%\n', '1994\n10.25%\n3.92%\n', '1993\n6.33%\n-5.46%\n', '1992\n11.79%\n-2.08%\n', '1991\n13.87%\n4.90%\n', '1990\n8.97%\n1.90%\n', '1989\n7.07%\n-2.31%\n', '1988\n9.38%\n0.58%\n', '1987\n8.80%\n0.07%\n', '1986\n8.73%\n3.17%\n', '1985\n5.56%\n-2.76%\n', '1984\n8.32%\n-3.55%\n', '1983\n11.87%\n3.98%\n', '1982\n7.89%\n-5.22%\n', '1981\n13.11%\n1.77%\n', '1980\n11.35%\n5.07%\n', '1979\n6.28%\n3.75%\n', '1978\n2.52%\n-5.78%\n', '1977\n8.31%\n15.94%\n', '1976\n-7.63%\n-13.38%\n', '1975\n5.75%\n-22.85%\n', '1974\n28.60%\n11.66%\n', '1973\n16.94%\n10.50%\n', '1972\n6.44%\n3.36%\n', '1971\n3.08%\n-2.01%\n', '1970\n5.09%\n5.68%\n', '1969\n-0.58%\n-3.82%\n', '1968\n3.24%\n-9.82%\n', '1967\n13.06%\n2.26%\n', '1966\n10.80%\n1.33%\n', '1965\n9.47%\n-3.88%\n', '1964\n13.36%\n10.41%\n', '1963\n2.95%\n-0.69%\n', '1962\n3.63%\n1.94%\n', '1961\n1.70%\n-0.08%\n', '1960\n1.78%\n-0.08%\n']

# %% [markdown]
# <a id = 'clean'></a>
# ## B. Data Cleaning

# %%
# Organizing Title Content

title = []
n = str('')
for i in range(len(tl)):

  if tl[i] != '\n':
    z = str(tl[i])
    n = str(n) + str(z)

  if tl[i] == '\n':
    title.append(n)
    n = str('')

title.pop()
title
# Out:
# ['India Inflation Rate - Historical Data']

# %%
# Organizing the Header Content

header = []
n = str('')
for i in range(len(hr)):

  if hr[i] != '\n':
    z = str(hr[i])
    n = str(n) + str(z)

  if hr[i] == '\n':
    header.append(n)
    n = str('')

header.pop()
header
# Out:
# ['Year', 'Inflation Rate (%)', 'Annual Change']

# %%
# Organizing the Values

values = []
column_values = []
a = str('')
for i in col_values:
  for j in range(len(i)):

    if i[j] != '\n':
      x = str(i[j])
      a = str(a) + str(x)

    if i[j] == '\n':
      values.append(a)
      a = str('')

  column_values.append(values)
  values = []

column_values
# Out:
# [['2019', '7.66%', '2.80%'],
#  ['2018', '4.86%', '2.37%'],
#  ['2017', '2.49%', '-2.45%'],
#  ['2016', '4.94%', '-0.93%'],
#  ['2015', '5.87%', '-0.48%'],
#  ['2014', '6.35%', '-4.55%'],
#  ['2013', '10.91%', '1.60%'],
#  ['2012', '9.31%', '0.45%'],
#  ['2011', '8.86%', '-3.13%'],
#  ['2010', '11.99%', '1.11%'],
#  ['2009', '10.88%', '2.53%'],
#  ['2008', '8.35%', '1.98%'],
#  ['2007', '6.37%', '0.58%'],
#  ['2006', '5.80%', '1.55%'],
#  ['2005', '4.25%', '0.48%'],
#  ['2004', '3.77%', '-0.04%'],
#  ['2003', '3.81%', '-0.49%'],
#  ['2002', '4.30%', '0.52%'],
#  ['2001', '3.78%', '-0.23%'],
#  ['2000', '4.01%', '-0.66%'],
#  ['1999', '4.67%', '-8.56%'],
#  ['1998', '13.23%', '6.07%'],
#  ['1997', '7.16%', '-1.81%'],
#  ['1996', '8.98%', '-1.25%'],
#  ['1995', '10.22%', '-0.02%'],
#  ['1994', '10.25%', '3.92%'],
#  ['1993', '6.33%', '-5.46%'],
#  ['1992', '11.79%', '-2.08%'],
#  ['1991', '13.87%', '4.90%'],
#  ['1990', '8.97%', '1.90%'],
#  ['1989', '7.07%', '-2.31%'],
#  ['1988', '9.38%', '0.58%'],
#  ['1987', '8.80%', '0.07%'],
#  ['1986', '8.73%', '3.17%'],
#  ['1985', '5.56%', '-2.76%'],
#  ['1984', '8.32%', '-3.55%'],
#  ['1983', '11.87%', '3.98%'],
#  ['1982', '7.89%', '-5.22%'],
#  ['1981', '13.11%', '1.77%'],
#  ['1980', '11.35%', '5.07%'],
#  ['1979', '6.28%', '3.75%'],
#  ['1978', '2.52%', '-5.78%'],
#  ['1977', '8.31%', '15.94%'],
#  ['1976', '-7.63%', '-13.38%'],
#  ['1975', '5.75%', '-22.85%'],
#  ['1974', '28.60%', '11.66%'],
#  ['1973', '16.94%', '10.50%'],
#  ['1972', '6.44%', '3.36%'],
#  ['1971', '3.08%', '-2.01%'],
#  ['1970', '5.09%', '5.68%'],
#  ['1969', '-0.58%', '-3.82%'],
#  ['1968', '3.24%', '-9.82%'],
#  ['1967', '13.06%', '2.26%'],
#  ['1966', '10.80%', '1.33%'],
#  ['1965', '9.47%', '-3.88%'],
#  ['1964', '13.36%', '10.41%'],
#  ['1963', '2.95%', '-0.69%'],
#  ['1962', '3.63%', '1.94%'],
#  ['1961', '1.70%', '-0.08%'],
#  ['1960', '1.78%', '-0.08%']]

# %%
# Converting the list into DataFrame

df = pd.DataFrame(column_values,columns = header)

# %%
# DataFrame

df
# Out:
#     Year Inflation Rate (%) Annual Change
# 0   2019              7.66%         2.80%
# 1   2018              4.86%         2.37%
# 2   2017              2.49%        -2.45%
# 3   2016              4.94%        -0.93%
# 4   2015              5.87%        -0.48%
# 5   2014              6.35%        -4.55%
# 6   2013             10.91%         1.60%
# 7   2012              9.31%         0.45%
# 8   2011              8.86%        -3.13%
# 9   2010             11.99%         1.11%
# 10  2009             10.88%         2.53%
# 11  2008              8.35%         1.98%
# 12  2007              6.37%         0.58%
# 13  2006              5.80%         1.55%
# 14  2005              4.25%         0.48%
# 15  2004              3.77%        -0.04%
# 16  2003              3.81%        -0.49%
# 17  2002              4.30%         0.52%
# 18  2001              3.78%        -0.23%
# 19  2000              4.01%        -0.66%
# 20  1999              4.67%        -8.56%
# 21  1998             13.23%         6.07%
# 22  1997              7.16%        -1.81%
# 23  1996              8.98%        -1.25%
# 24  1995             10.22%        -0.02%
# 25  1994             10.25%         3.92%
# 26  1993              6.33%        -5.46%
# 27  1992             11.79%        -2.08%
# 28  1991             13.87%         4.90%
# 29  1990              8.97%         1.90%
# 30  1989              7.07%        -2.31%
# 31  1988              9.38%         0.58%
# 32  1987              8.80%         0.07%
# 33  1986              8.73%         3.17%
# 34  1985              5.56%        -2.76%
# 35  1984              8.32%        -3.55%
# 36  1983             11.87%         3.98%
# 37  1982              7.89%        -5.22%
# 38  1981             13.11%         1.77%
# 39  1980             11.35%         5.07%
# 40  1979              6.28%         3.75%
# 41  1978              2.52%        -5.78%
# 42  1977              8.31%        15.94%
# 43  1976             -7.63%       -13.38%
# 44  1975              5.75%       -22.85%
# 45  1974             28.60%        11.66%
# 46  1973             16.94%        10.50%
# 47  1972              6.44%         3.36%
# 48  1971              3.08%        -2.01%
# 49  1970              5.09%         5.68%
# 50  1969             -0.58%        -3.82%
# 51  1968              3.24%        -9.82%
# 52  1967             13.06%         2.26%
# 53  1966             10.80%         1.33%
# 54  1965              9.47%        -3.88%
# 55  1964             13.36%        10.41%
# 56  1963              2.95%        -0.69%
# 57  1962              3.63%         1.94%
# 58  1961              1.70%        -0.08%
# 59  1960              1.78%        -0.08%

# %%
# Checking DataTypes

df.dtypes
# Out:
# Year                  object
# Inflation Rate (%)    object
# Annual Change         object
# dtype: object

# %%
# Dropping the Annual Change column

df.drop(columns = 'Annual Change',inplace = True)

# %%
# Removing Special Characters

df['Inflation Rate (%)'].replace(to_replace='%', value='', inplace=True, regex=True)

# %%
# Converting the DataTypes:

df['Year'] = df['Year'].astype('int64')
df['Inflation Rate (%)'] = df['Inflation Rate (%)'].astype('float')

# %%
# Confirmation

df.dtypes
# Out:
# Year                    int64
# Inflation Rate (%)    float64
# dtype: object

# %%
# Saving as CSV
df.to_csv('/content/drive/My Drive/Colab Notebooks/'+ title[0] +'.csv' ,index = False)

# %% [markdown]
# # Currency Conversion `Web Scrapping`
#
# ## Table of Content
# [C. Data Gathering](#gather_cr)\
# [D. Data Cleaning](#clean_cr)

# %%
# Importing Libraries

from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# <a id = 'gather_cr'></a>
# ## C. Data Gathering

# %%
# Getting URL

url = 'https://en.wikipedia.org/wiki/Exchange_rate_history_of_the_Indian_rupee'

html_content = requests.get(url).text

# %%
# URL Content

soup = BeautifulSoup(html_content, "lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Exchange rate history of the Indian rupee - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"a81cfd89-ec70-4690-8509-135049a0ca54","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Exchange_rate_history_of_the_Indian_rupee","wgTitle":"Exchange rate history of the Indian rupee","wgCurRevisionId":987771429,"wgRevisionId":987771429,"wgArticleId":43723456,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Rupee","Coins of India","Denominations (currency)","Currency lists","Foreign exchange market"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Exchange_rate_history_of_the_Indian_rupee",
# "wgRelevantArticleId":43723456,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0,"wgULSPosition":"interlanguage","wgWikibaseItemId":"Q18387468"};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","jquery.tablesorter.styles":
# "ready","jquery.makeCollapsible.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","skins.vector.legacy.js","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.refToolbar","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp"];
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });});
#   </script>
#   <link href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector">
#   </script>
#   <meta content="" name="ResourceLoaderDynamicStyles"/>
#   <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <meta content="MediaWiki 1.36.0-wmf.16" name="generator"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="origin-when-crossorigin" name="referrer"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <link href="//upload.wikimedia.org" rel="preconnect"/>
#   <link href="//en.m.wikipedia.org/wiki/Exchange_rate_history_of_the_Indian_rupee" media="only screen and (max-width: 720px)" rel="alternate"/>
#   <link href="/w/index.php?title=Exchange_rate_history_of_the_Indian_rupee&amp;action=edit" rel="alternate" title="Edit this page" type="application/x-wiki"/>
#   <link href="/w/index.php?title=Exchange_rate_history_of_the_Indian_rupee&amp;action=edit" rel="edit" title="Edit this page"/>
#   <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
#   <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
#   <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
#   <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
#   <link href="//creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
#   <link href="https://en.wikipedia.org/wiki/Exchange_rate_history_of_the_Indian_rupee" rel="canonical"/>
#   <link href="//login.wikimedia.org" rel="dns-prefetch"/>
#   <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
#  </head>
#  <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-Exchange_rate_history_of_the_Indian_rupee rootpage-Exchange_rate_history_of_the_Indian_rupee skin-vector action-view skin-vector-legacy">
#   <div class="noprint" id="mw-page-base">
#   </div>
#   <div class="noprint" id="mw-head-base">
#   </div>
#   <div class="mw-body" id="content" role="main">
#    <a id="top">
#    </a>
#    <div class="mw-body-content" id="siteNotice">
#     <!-- CentralNotice -->
#    </div>
#    <div class="mw-indicators mw-body-content">
#    </div>
#    <h1 class="firstHeading" id="firstHeading" lang="en">
#     Exchange rate history of the Indian rupee
#    </h1>
#    <div class="mw-body-content" id="bodyContent">
#     <div class="noprint" id="siteSub">
#      From Wikipedia, the free encyclopedia
#     </div>
#     <div id="contentSub">
#     </div>
#     <div id="contentSub2">
#     </div>
#     <div id="jump-to-nav">
#     </div>
#     <a class="mw-jump-link" href="#mw-head">
#      Jump to navigation
#     </a>
#     <a class="mw-jump-link" href="#searchInput">
#      Jump to search
#     </a>
#     <div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="en">
#      <div class="mw-parser-output">
#       <div class="floatright">
#        <a class="image" href="/wiki/File:Indian_Rupee_symbol.svg">
#         <img alt="Indian Rupee symbol.svg" data-file-height="753" data-file-width="512" decoding="async" height="147" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/ee/Indian_Rupee_symbol.svg/100px-Indian_Rupee_symbol.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/ee/Indian_Rupee_symbol.svg/150px-Indian_Rupee_symbol.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/e/ee/Indian_Rupee_symbol.svg/200px-Indian_Rupee_symbol.svg.png 2x" width="100"/>
#        </a>
#       </div>
#       <p>
#        This is a list of tables showing the historical timeline of the exchange rate for the Indian
#        <a href="/wiki/Rupee" title="Rupee">
#         rupee
#        </a>
#        (INR) against the
#        <a href="/wiki/Special_drawing_rights" title="Special drawing rights">
#         special drawing rights
#        </a>
#        unit (SDR),
#        <a href="/wiki/United_States_dollar" title="United States dollar">
#         United States dollar
#        </a>
#        (USD),
#        <a href="/wiki/Pound_sterling" title="Pound sterling">
#         pound sterling
#        </a>
#        (GBP),
#        <a class="mw-redirect" href="/wiki/Deutsche_mark" title="Deutsche mark">
#         Deutsche mark
#        </a>
#        (DM),
#        <a href="/wiki/Euro" title="Euro">
#         euro
#        </a>
#        (EUR) and
#        <a href="/wiki/Japanese_yen" title="Japanese yen">
#         Japanese yen
#        </a>
#        (JPY).
#       </p>
#       <p>
#        The US dollar was worth
#        <span style="white-space: nowrap">
#         ₹
#        </span>
#        3 in 1947 not 1,
#        <sup class="reference" id="cite_ref-1">
#         <a href="#cite_note-1">
#          [1]
#         </a>
#        </sup>
#        and
#        <span style="white-space: nowrap">
#         ₹
#        </span>
#        69.9 in 2018.
#        <sup class="reference" id="cite_ref-rbi19130_2-0">
#         <a href="#cite_note-rbi19130-2">
#          [2]
#         </a>
#        </sup>
#       </p>
#       <h2>
#        <span class="mw-headline" id="Notes">
#         Notes
#        </span>
#        <span class="mw-editsection">
#         <span class="mw-editsection-bracket">
#          [
#         </span>
#         <a href="/w/index.php?title=Exchange_rate_history_of_the_Indian_rupee&amp;action=edit&amp;section=1" title="Edit section: Notes">
#          edit
#         </a>
#         <span class="mw-editsection-bracket">
#          ]
#         </span>
#        </span>
#       </h2>
#       <ul>
#        <li>
#         The data on exchange rate for
#         <a href="/wiki/Japanese_yen" title="Japanese yen">
#          Japanese Yen
#         </a>
#         is in per 100 Yen.
#        </li>
#        <li>
#         The end year rate for 1998-99 pertain to March 26, 1999 of
#         <a href="/wiki/Deutsche_Mark" title="Deutsche Mark">
#          Deutsche Mark
#         </a>
#         rate.
#        </li>
#        <li>
#         Data from 1971 to 1991-92 are based on official exchange rates.
#        </li>
#        <li>
#         Data from 1992 to 1993 onward are based on FEDAI (Foreign Exchange Dealers' Association of India) indicative rates.
#        </li>
#        <li>
#         Data from 1971 to 1972-73 for the Deutsche Mark and the Japanese Yen are cross rates with the
#         <a href="/wiki/United_States_dollar" title="United States dollar">
#          US Dollar
#         </a>
#         .
#        </li>
#        <li>
#         The
#         <a href="/wiki/Euro" title="Euro">
#          Euro
#         </a>
#         replaced the
#         <a href="/wiki/Deutsche_Mark" title="Deutsche Mark">
#          Deutsche Mark
#         </a>
#         w.e.f. January 1, 1999.
#        </li>
#       </ul>
#       <h2>
#        <span class="mw-headline" id="1974_to_2019">
#         1974 to 2019
#        </span>
#        <span class="mw-editsection">
#         <span class="mw-editsection-bracket">
#          [
#         </span>
#         <a href="/w/index.php?title=Exchange_rate_history_of_the_Indian_rupee&amp;action=edit&amp;section=2" title="Edit section: 1974 to 2019">
#          edit
#         </a>
#         <span class="mw-editsection-bracket">
#          ]
#         </span>
#        </span>
#       </h2>
#       <table class="wikitable sortable">
#        <caption>
#         Exchange Rate of the Indian Rupee vis-a-vis the SDR, USD, GBP, DM and JPY (FY, annual average and end-year rates)
#         <sup class="reference" id="cite_ref-rbi15268_3-0">
#          <a href="#cite_note-rbi15268-3">
#           [3]
#          </a>
#         </sup>
#         <sup class="reference" id="cite_ref-rbi19131_4-0">
#          <a href="#cite_note-rbi19131-4">
#           [4]
#          </a>
#         </sup>
#        </caption>
#        <tbody>
#         <tr>
#          <th>
#           Year
#          </th>
#          <th>
#           SDR (average)
#          </th>
#          <th>
#           SDR (end year)
#          </th>
#          <th>
#           USD (average)
#          </th>
#          <th>
#           USD (end year)
#          </th>
#          <th>
#           GBP (average)
#          </th>
#          <th>
#           GBP (end year)
#          </th>
#          <th>
#           DM/EUR (average)
#          </th>
#          <th>
#           DM/EUR (end year)
#          </th>
#          <th>
#           JPY (average)
#          </th>
#          <th>
#           JPY (end year)
#          </th>
#         </tr>
#         <tr>
#          <td>
#           1974-75
#          </td>
#          <td>
#           9.6233
#          </td>
#          <td>
#           9.723
#          </td>
#          <td>
#           7.9408
#          </td>
#          <td>
#           7.794
#          </td>
#          <td>
#           18.8
#          </td>
#          <td>
#           18.776
#          </td>
#          <td>
#           3.1917
#          </td>
#          <td>
#           3.324
#          </td>
#          <td>
#           3
#          </td>
#          <td>
#           2.7
#          </td>
#         </tr>
#         <tr>
#          <td>
#           1975-76
#          </td>
#          <td>
#           10.3642
#          </td>
#          <td>
#           10.375
#          </td>
#          <td>
#           8.6825
#          </td>
#          <td>
#           8.973
#          </td>
#          <td>
#           18.3933
#          </td>
#          <td>
#           17.19
#          </td>
#          <td>
#           3.4458
#          </td>
#          <td>
#           3.535
#          </td>
#          <td>
#           3
#          </td>
#          <td>
#           3
#          </td>
#         </tr>
#         <tr>
#          <td>
#           1976-77
#          </td>
#          <td>
#           10.35
#          </td>
#          <td>
#           10.206
#          </td>
#          <td>
#           8.9775
#          </td>
#          <td>
#           8.804
#          </td>
#          <td>
#           15.5733
#          </td>
#          <td>
#           15.144
#          </td>
#          <td>
#           3.6308
#          </td>
#          <td>
#           3.686
#          </td>
#          <td>
#           3
#          </td>
#          <td>
#           3.2
#          </td>
#         </tr>
#         <tr>
#          <td>
#           
#          </td>
#         </tr>
#         <tr>
#          <td>
#           2016-17
#          </td>
#          <td>
#           92.6156
#          </td>
#          <td>
#           87.9763
#          </td>
#          <td>
#           67.0720
#          </td>
#          <td>
#           64.8386
#          </td>
#          <td>
#           87.6897
#          </td>
#          <td>
#           80.8797
#          </td>
#          <td>
#           62.0350
#          </td>
#          <td>
#           57.9600
#          </td>
#          <td>
#           73.6087
#          </td>
#          <td>
#           69.2476
#          </td>
#         </tr>
#         <tr>
#          <td>
#           2017-18
#          </td>
#          <td>
#           90.8989
#          </td>
#          <td>
#           94.8065
#          </td>
#          <td>
#           64.4549
#          </td>
#          <td>
#           65.0441
#          </td>
#          <td>
#           85.5129
#          </td>
#          <td>
#           92.2846
#          </td>
#          <td>
#           58.1822
#          </td>
#          <td>
#           61.5400
#          </td>
#          <td>
#           75.4378
#          </td>
#          <td>
#           80.6222
#          </td>
#         </tr>
#         <tr>
#          <td>
#           2018-19
#          </td>
#          <td>
#           98.0361
#          </td>
#          <td>
#           96.0273
#          </td>
#          <td>
#           69.9229
#          </td>
#          <td>
#           69.1713
#          </td>
#          <td>
#           91.7865
#          </td>
#          <td>
#           90.4756
#          </td>
#          <td>
#           63.0468
#          </td>
#          <td>
#           62.5200
#          </td>
#          <td>
#           80.9580
#          </td>
#          <td>
#           77.7024
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <h2>
#        <span class="mw-headline" id="References">
#         References
#        </span>
#        <span class="mw-editsection">
#         <span class="mw-editsection-bracket">
#          [
#         </span>
#         <a href="/w/index.php?title=Exchange_rate_history_of_the_Indian_rupee&amp;action=edit&amp;section=3" title="Edit section: References">
#          edit
#         </a>
#         <span class="mw-editsection-bracket">
#          ]
#         </span>
#        </span>
#       </h2>
#       <div class="reflist" style="list-style-type: decimal;">
#        <div class="mw-references-wrap">
#         <ol class="references">
#          <li id="cite_note-1">
#           <span class="mw-cite-backlink">
#            <b>
#             <a href="#cite_ref-1">
#              ^
#             </a>
#            </b>
#           </span>
#           <span class="reference-text">
#            <cite class="citation news cs1">
#             <a class="external text" href="https://archive.is/20130829085318/http://articles.economictimes.indiatimes.com/2013-08-24/news/41444029_1_indian-rupee-american-currency-continued-dollar-demand" rel="nofollow">
#              "Rupee's journey since Independence: Down by 65 times against dollar"
#             </a>
#             .
#             <i>
#              <a href="/wiki/The_Economic_Times" title="The Economic Times">
#               The Economic Times
#              </a>
#             </i>
#             .
#             <a class="mw-redirect" href="/wiki/Bennett,_Coleman_%26_Co" title="Bennett, Coleman &amp; Co">
#              Bennett, Coleman &amp; Co
#             </a>
#             . 2013-08-04. Archived from
#             <a class="external text" href="http://articles.economictimes.indiatimes.com/2013-08-24/news/41444029_1_indian-rupee-american-currency-continued-dollar-demand" rel="nofollow">
#              the original
#             </a>
#             on 2013-08-29
#             <span class="reference-accessdate">
#              . Retrieved
#              <span class="nowrap">
#               2014-09-02
#              </span>
#             </span>
#             .
#            </cite>
#            <span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=The+Economic+Times&amp;rft.atitle=Rupee%27s+journey+since+Independence%3A+Down+by+65+times+against+dollar&amp;rft.date=2013-08-04&amp;rft_id=http%3A%2F%2Farticles.economictimes.indiatimes.com%2F2013-08-24%2Fnews%2F41444029_1_indian-rupee-american-currency-continued-dollar-demand&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AExchange+rate+history+of+the+Indian+rupee">
#            </span>
#            <style data-mw-deduplicate="TemplateStyles:r982806391">
#             .mw-parser-output cite.citation{font-style:inherit}.mw-parser-output .citation q{quotes:"\"""\"""'""'"}.mw-parser-output .id-lock-free a,.mw-parser-output .citation .cs1-lock-free a{background:linear-gradient(transparent,transparent),url("//upload.wikimedia.org/wikipedia/commons/6/65/Lock-green.svg")right 0.1em center/9px no-repeat}.mw-parser-output .id-lock-limited a,.mw-parser-output .id-lock-registration a,.mw-parser-output .citation .cs1-lock-limited a,.mw-parser-output .citation .cs1-lock-registration a{background:linear-gradient(transparent,transparent),url("//upload.wikimedia.org/wikipedia/commons/d/d6/Lock-gray-alt-2.svg")right 0.1em center/9px no-repeat}.mw-parser-output .id-lock-subscription a,.mw-parser-output .citation .cs1-lock-subscription a{background:linear-gradient(transparent,transparent),url("//upload.wikimedia.org/wikipedia/commons/a/aa/Lock-red-alt-2.svg")right 0.1em center/9px no-repeat}.mw-parser-output .cs1-subscription,.mw-parser-output .cs1-registration{color:#555}.mw-parser-output .cs1-subscription span,.mw-parser-output .cs1-registration span{border-bottom:1px dotted;cursor:help}.mw-parser-output .cs1-ws-icon a{background:linear-gradient(transparent,transparent),url("//upload.wikimedia.org/wikipedia/commons/4/4c/Wikisource-logo.svg")right 0.1em center/12px no-repeat}.mw-parser-output code.cs1-code{color:inherit;background:inherit;border:none;padding:inherit}.mw-parser-output .cs1-hidden-error{display:none;font-size:100%}.mw-parser-output .cs1-visible-error{font-size:100%}.mw-parser-output .cs1-maint{display:none;color:#33aa33;margin-left:0.3em}.mw-parser-output .cs1-subscription,.mw-parser-output .cs1-registration,.mw-parser-output .cs1-format{font-size:95%}.mw-parser-output .cs1-kern-left,.mw-parser-output .cs1-kern-wl-left{padding-left:0.2em}.mw-parser-output .cs1-kern-right,.mw-parser-output .cs1-kern-wl-right{padding-right:0.2em}.mw-parser-output .citation .mw-selflink{font-weight:inherit}
#            </style>
#           </span>
#          </li>
#          <li id="cite_note-rbi19130-2">
#           <span class="mw-cite-backlink">
#            <b>
#             <a href="#cite_ref-rbi19130_2-0">
#              ^
#             </a>
#            </b>
#           </span>
#           <span class="reference-text">
#            <cite class="citation magazine cs1">
#             <a class="external text" href="https://www.rbi.org.in/Scripts/PublicationsView.aspx?id=19130" rel="nofollow">
#              "Table 139 : Exchange Rate of the Indian Rupee vis-à-vis the Sdr, US Dollar, Pound Sterling, D.M./Euro and Japanese Yen (Calendar Year - Annual Average)"
#             </a>
#             .
#             <i>
#              <a class="new" href="/w/index.php?title=Handbook_of_Statistics_on_Indian_Economy&amp;action=edit&amp;redlink=1" title="Handbook of Statistics on Indian Economy (page does not exist)">
#               Handbook of Statistics on Indian Economy
#              </a>
#             </i>
#             .
#             <a href="/wiki/Reserve_Bank_of_India" title="Reserve Bank of India">
#              Reserve Bank of India
#             </a>
#             . 2019-09-15.
#             <a class="external text" href="https://archive.today/20191109140022/https://www.rbi.org.in/Scripts/PublicationsView.aspx?id=19130" rel="nofollow">
#              Archived
#             </a>
#             from the original on 2019-11-09
#             <span class="reference-accessdate">
#              . Retrieved
#              <span class="nowrap">
#               2019-11-09
#              </span>
#             </span>
#             .
#            </cite>
#            <span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=Handbook+of+Statistics+on+Indian+Economy&amp;rft.atitle=Table+139+%3A+Exchange+Rate+of+the+Indian+Rupee+vis-%C3%A0-vis+the+Sdr%2C+US+Dollar%2C+Pound+Sterling%2C+D.M.%2FEuro+and+Japanese+Yen+%28Calendar+Year+-+Annual+Average%29&amp;rft.date=2019-09-15&amp;rft_id=https%3A%2F%2Fwww.rbi.org.in%2FScripts%2FPublicationsView.aspx%3Fid%3D19130&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AExchange+rate+history+of+the+Indian+rupee">
#            </span>
#            <link href="mw-data:TemplateStyles:r982806391" rel="mw-deduplicated-inline-style"/>
#           </span>
#          </li>
#          <li id="cite_note-rbi15268-3">
#           <span class="mw-cite-backlink">
#            <b>
#             <a href="#cite_ref-rbi15268_3-0">
#              ^
#             </a>
#            </b>
#           </span>
#           <span class="reference-text">
#            <cite class="citation magazine cs1">
#             <a class="external text" href="https://www.rbi.org.in/scripts/PublicationsView.aspx?id=15268" rel="nofollow">
#              "Table 140 : Exchange Rate of the Indian Rupee vis-à-vis the Sdr, US Dollar, Pound Sterling, D.M./Euro and Japanese Yen (Financial Year-Annual Average and end-Year Rates)"
#             </a>
#             .
#             <i>
#              Handbook of Statistics on Indian Economy
#             </i>
#             . Reserve Bank of India. 2013-09-16.
#             <a class="external text" href="https://archive.today/20140902173109/http://www.rbi.org.in/scripts/PublicationsView.aspx?id=15268" rel="nofollow">
#              Archived
#             </a>
#             from the original on 2014-09-02
#             <span class="reference-accessdate">
#              . Retrieved
#              <span class="nowrap">
#               2019-11-09
#              </span>
#             </span>
#             .
#            </cite>
#            <span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=Handbook+of+Statistics+on+Indian+Economy&amp;rft.atitle=Table+140+%3A+Exchange+Rate+of+the+Indian+Rupee+vis-%C3%A0-vis+the+Sdr%2C+US+Dollar%2C+Pound+Sterling%2C+D.M.%2FEuro+and+Japanese+Yen+%28Financial+Year-Annual+Average+and+end-Year+Rates%29&amp;rft.date=2013-09-16&amp;rft_id=https%3A%2F%2Fwww.rbi.org.in%2Fscripts%2FPublicationsView.aspx%3Fid%3D15268&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AExchange+rate+history+of+the+Indian+rupee">
#            </span>
#            <link href="mw-data:TemplateStyles:r982806391" rel="mw-deduplicated-inline-style"/>
#           </span>
#          </li>
#          <li id="cite_note-rbi19131-4">
#           <span class="mw-cite-backlink">
#            <b>
#             <a href="#cite_ref-rbi19131_4-0">
#              ^
#             </a>
#            </b>
#           </span>
#           <span class="reference-text">
#            <cite class="citation magazine cs1">
#             <a class="external text" href="https://www.rbi.org.in/Scripts/PublicationsView.aspx?id=19131" rel="nofollow">
#              "Table 140 : Exchange Rate of the Indian Rupee vis-à-vis the Sdr, US Dollar, Pound Sterling, D.M./Euro and Japanese Yen (Financial Year-Annual Average and end-Year Rates)"
#             </a>
#             .
#             <i>
#              Handbook of Statistics on Indian Economy
#             </i>
#             . Reserve Bank of India. 2019-09-15.
#             <a class="external text" href="https://archive.today/20191109141331/https://www.rbi.org.in/Scripts/PublicationsView.aspx?id=19131" rel="nofollow">
#              Archived
#             </a>
#             from the original on 2019-11-09
#             <span class="reference-accessdate">
#              . Retrieved
#              <span class="nowrap">
#               2019-11-09
#              </span>
#             </span>
#             .
#            </cite>
#            <span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=Handbook+of+Statistics+on+Indian+Economy&amp;rft.atitle=Table+140+%3A+Exchange+Rate+of+the+Indian+Rupee+vis-%C3%A0-vis+the+Sdr%2C+US+Dollar%2C+Pound+Sterling%2C+D.M.%2FEuro+and+Japanese+Yen+%28Financial+Year-Annual+Average+and+end-Year+Rates%29&amp;rft.date=2019-09-15&amp;rft_id=https%3A%2F%2Fwww.rbi.org.in%2FScripts%2FPublicationsView.aspx%3Fid%3D19131&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AExchange+rate+history+of+the+Indian+rupee">
#            </span>
#            <link href="mw-data:TemplateStyles:r982806391" rel="mw-deduplicated-inline-style"/>
#           </span>
#          </li>
#         </ol>
#        </div>
#       </div>
#       <div aria-labelledby="Currencies_named_rupee_or_similar" class="navbox" role="navigation" style="padding:3px">
#        <table class="nowraplinks mw-collapsible autocollapse navbox-inner" style="border-spacing:0;background:transparent;color:inherit">
#         <tbody>
#          <tr>
#           <th class="navbox-title" colspan="2" scope="col">
#            <div class="plainlinks hlist navbar mini">
#             <ul>
#              <li class="nv-view">
#               <a href="/wiki/Template:Rupee" title="Template:Rupee">
#                <abbr style=";;background:none transparent;border:none;-moz-box-shadow:none;-webkit-box-shadow:none;box-shadow:none; padding:0;" title="View this template">
#                 v
#                </abbr>
#               </a>
#              </li>
#              <li class="nv-talk">
#               <a href="/wiki/Template_talk:Rupee" title="Template talk:Rupee">
#                <abbr style=";;background:none transparent;border:none;-moz-box-shadow:none;-webkit-box-shadow:none;box-shadow:none; padding:0;" title="Discuss this template">
#                 t
#                </abbr>
#               </a>
# ...
#           Article
#          </a>
#         </li>
#         <li id="ca-talk">
#          <a accesskey="t" href="/wiki/Talk:Exchange_rate_history_of_the_Indian_rupee" rel="discussion" title="Discuss improvements to the content page [t]">
#           Talk
#          </a>
#         </li>
#        </ul>
#       </div>
#      </nav>
#      <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#      <nav aria-labelledby="p-variants-label" class="mw-portlet mw-portlet-variants emptyPortlet vector-menu vector-menu-dropdown" id="p-variants" role="navigation">
#       <input aria-labelledby="p-variants-label" class="vector-menu-checkbox" type="checkbox"/>
#       <h3 id="p-variants-label">
#        <span>
#         Variants
#        </span>
#       </h3>
#       <div class="vector-menu-content">
#        <ul class="vector-menu-content-list">
#        </ul>
#       </div>
#      </nav>
#     </div>
#     <div id="right-navigation">
#      <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#      <nav aria-labelledby="p-views-label" class="mw-portlet mw-portlet-views vector-menu vector-menu-tabs" id="p-views" role="navigation">
#       <h3 id="p-views-label">
#        <span>
#         Views
#        </span>
#       </h3>
#       <div class="vector-menu-content">
#        <ul class="vector-menu-content-list">
#         <li class="selected" id="ca-view">
#          <a href="/wiki/Exchange_rate_history_of_the_Indian_rupee">
#           Read
#          </a>
#         </li>
#         <li id="ca-edit">
#          <a accesskey="e" href="/w/index.php?title=Exchange_rate_history_of_the_Indian_rupee&amp;action=edit" title="Edit this page [e]">
#           Edit
#          </a>
#         </li>
#         <li id="ca-history">
#          <a accesskey="h" href="/w/index.php?title=Exchange_rate_history_of_the_Indian_rupee&amp;action=history" title="Past revisions of this page [h]">
#           View history
#          </a>
#         </li>
#        </ul>
#       </div>
#      </nav>
#      <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#      <nav aria-labelledby="p-cactions-label" class="mw-portlet mw-portlet-cactions emptyPortlet vector-menu vector-menu-dropdown" id="p-cactions" role="navigation">
#       <input aria-labelledby="p-cactions-label" class="vector-menu-checkbox" type="checkbox"/>
#       <h3 id="p-cactions-label">
#        <span>
#         More
#        </span>
#       </h3>
#       <div class="vector-menu-content">
#        <ul class="vector-menu-content-list">
#        </ul>
#       </div>
#      </nav>
#      <div id="p-search" role="search">
#       <h3>
#        <label for="searchInput">
#         Search
#        </label>
#       </h3>
#       <form action="/w/index.php" id="searchform">
#        <div data-search-loc="header-navigation" id="simpleSearch">
#         <input accesskey="f" autocapitalize="sentences" id="searchInput" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" type="search"/>
#         <input name="title" type="hidden" value="Special:Search"/>
#         <input class="searchButton mw-fallbackSearchButton" id="mw-searchButton" name="fulltext" title="Search Wikipedia for this text" type="submit" value="Search"/>
#         <input class="searchButton" id="searchButton" name="go" title="Go to a page with this exact name if it exists" type="submit" value="Go"/>
#        </div>
#       </form>
#      </div>
#     </div>
#    </div>
#    <div id="mw-panel">
#     <div id="p-logo" role="banner">
#      <a class="mw-wiki-logo" href="/wiki/Main_Page" title="Visit the main page">
#      </a>
#     </div>
#     <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#     <nav aria-labelledby="p-navigation-label" class="mw-portlet mw-portlet-navigation vector-menu vector-menu-portal portal portal-first" id="p-navigation" role="navigation">
#      <h3 id="p-navigation-label">
#       <span>
#        Navigation
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li id="n-mainpage-description">
#         <a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]">
#          Main page
#         </a>
#        </li>
#        <li id="n-contents">
#         <a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia">
#          Contents
#         </a>
#        </li>
#        <li id="n-currentevents">
#         <a href="/wiki/Portal:Current_events" title="Articles related to current events">
#          Current events
#         </a>
#        </li>
#        <li id="n-randompage">
#         <a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]">
#          Random article
#         </a>
#        </li>
#        <li id="n-aboutsite">
#         <a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works">
#          About Wikipedia
#         </a>
#        </li>
#        <li id="n-contactpage">
#         <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">
#          Contact us
#         </a>
#        </li>
#        <li id="n-sitesupport">
#         <a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us by donating to the Wikimedia Foundation">
#          Donate
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#     <nav aria-labelledby="p-interaction-label" class="mw-portlet mw-portlet-interaction vector-menu vector-menu-portal portal" id="p-interaction" role="navigation">
#      <h3 id="p-interaction-label">
#       <span>
#        Contribute
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li id="n-help">
#         <a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">
#          Help
#         </a>
#        </li>
#        <li id="n-introduction">
#         <a href="/wiki/Help:Introduction" title="Learn how to edit Wikipedia">
#          Learn to edit
#         </a>
#        </li>
#        <li id="n-portal">
#         <a href="/wiki/Wikipedia:Community_portal" title="The hub for editors">
#          Community portal
#         </a>
#        </li>
#        <li id="n-recentchanges">
#         <a accesskey="r" href="/wiki/Special:RecentChanges" title="A list of recent changes to Wikipedia [r]">
#          Recent changes
#         </a>
#        </li>
#        <li id="n-upload">
#         <a href="/wiki/Wikipedia:File_Upload_Wizard" title="Add images or other media for use on Wikipedia">
#          Upload file
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#     <nav aria-labelledby="p-tb-label" class="mw-portlet mw-portlet-tb vector-menu vector-menu-portal portal" id="p-tb" role="navigation">
#      <h3 id="p-tb-label">
#       <span>
#        Tools
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li id="t-whatlinkshere">
#         <a accesskey="j" href="/wiki/Special:WhatLinksHere/Exchange_rate_history_of_the_Indian_rupee" title="List of all English Wikipedia pages containing links to this page [j]">
#          What links here
#         </a>
#        </li>
#        <li id="t-recentchangeslinked">
#         <a accesskey="k" href="/wiki/Special:RecentChangesLinked/Exchange_rate_history_of_the_Indian_rupee" rel="nofollow" title="Recent changes in pages linked from this page [k]">
#          Related changes
#         </a>
#        </li>
#        <li id="t-upload">
#         <a accesskey="u" href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]">
#          Upload file
#         </a>
#        </li>
#        <li id="t-specialpages">
#         <a accesskey="q" href="/wiki/Special:SpecialPages" title="A list of all special pages [q]">
#          Special pages
#         </a>
#        </li>
#        <li id="t-permalink">
#         <a href="/w/index.php?title=Exchange_rate_history_of_the_Indian_rupee&amp;oldid=987771429" title="Permanent link to this revision of this page">
#          Permanent link
#         </a>
#        </li>
#        <li id="t-info">
#         <a href="/w/index.php?title=Exchange_rate_history_of_the_Indian_rupee&amp;action=info" title="More information about this page">
#          Page information
#         </a>
#        </li>
#        <li id="t-cite">
#         <a href="/w/index.php?title=Special:CiteThisPage&amp;page=Exchange_rate_history_of_the_Indian_rupee&amp;id=987771429&amp;wpFormIdentifier=titleform" title="Information on how to cite this page">
#          Cite this page
#         </a>
#        </li>
#        <li id="t-wikibase">
#         <a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q18387468" title="Structured data on this page hosted by Wikidata [g]">
#          Wikidata item
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#     <nav aria-labelledby="p-coll-print_export-label" class="mw-portlet mw-portlet-coll-print_export vector-menu vector-menu-portal portal" id="p-coll-print_export" role="navigation">
#      <h3 id="p-coll-print_export-label">
#       <span>
#        Print/export
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li id="coll-download-as-rl">
#         <a href="/w/index.php?title=Special:DownloadAsPdf&amp;page=Exchange_rate_history_of_the_Indian_rupee&amp;action=show-download-screen" title="Download this page as a PDF file">
#          Download as PDF
#         </a>
#        </li>
#        <li id="t-print">
#         <a accesskey="p" href="/w/index.php?title=Exchange_rate_history_of_the_Indian_rupee&amp;printable=yes" title="Printable version of this page [p]">
#          Printable version
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#     <nav aria-labelledby="p-lang-label" class="mw-portlet mw-portlet-lang vector-menu vector-menu-portal portal" id="p-lang" role="navigation">
#      <h3 id="p-lang-label">
#       <span>
#        Languages
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#       </ul>
#       <div class="after-portlet after-portlet-lang">
#        <span class="uls-after-portlet-link">
#        </span>
#        <span class="wb-langlinks-add wb-langlinks-link">
#         <a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q18387468#sitelinks-wikipedia" title="Add interlanguage links">
#          Add links
#         </a>
#        </span>
#       </div>
#      </div>
#     </nav>
#    </div>
#   </div>
#   <footer class="mw-footer" id="footer" role="contentinfo">
#    <ul id="footer-info">
#     <li id="footer-info-lastmod">
#      This page was last edited on 9 November 2020, at 04:02
#      <span class="anonymous-show">
#       (UTC)
#      </span>
#      .
#     </li>
#     <li id="footer-info-copyright">
#      Text is available under the
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License" rel="license">
#       Creative Commons Attribution-ShareAlike License
#      </a>
#      <a href="//creativecommons.org/licenses/by-sa/3.0/" rel="license" style="display:none;">
#      </a>
#      ;
# additional terms may apply.  By using this site, you agree to the
#      <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">
#       Terms of Use
#      </a>
#      and
#      <a href="//foundation.wikimedia.org/wiki/Privacy_policy">
#       Privacy Policy
#      </a>
#      . Wikipedia® is a registered trademark of the
#      <a href="//www.wikimediafoundation.org/">
#       Wikimedia Foundation, Inc.
#      </a>
#      , a non-profit organization.
#     </li>
#    </ul>
#    <ul id="footer-places">
#     <li id="footer-places-privacy">
#      <a class="extiw" href="https://foundation.wikimedia.org/wiki/Privacy_policy" title="wmf:Privacy policy">
#       Privacy policy
#      </a>
#     </li>
#     <li id="footer-places-about">
#      <a href="/wiki/Wikipedia:About" title="Wikipedia:About">
#       About Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-disclaimer">
#      <a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">
#       Disclaimers
#      </a>
#     </li>
#     <li id="footer-places-contact">
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">
#       Contact Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-mobileview">
#      <a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=Exchange_rate_history_of_the_Indian_rupee&amp;mobileaction=toggle_view_mobile">
#       Mobile view
#      </a>
#     </li>
#     <li id="footer-places-developers">
#      <a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">
#       Developers
#      </a>
#     </li>
#     <li id="footer-places-statslink">
#      <a href="https://stats.wikimedia.org/#/en.wikipedia.org">
#       Statistics
#      </a>
#     </li>
#     <li id="footer-places-cookiestatement">
#      <a href="https://foundation.wikimedia.org/wiki/Cookie_statement">
#       Cookie statement
#      </a>
#     </li>
#    </ul>
#    <ul class="noprint" id="footer-icons">
#     <li id="footer-copyrightico">
#      <a href="https://wikimediafoundation.org/">
#       <img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88"/>
#      </a>
#     </li>
#     <li id="footer-poweredbyico">
#      <a href="https://www.mediawiki.org/">
#       <img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/footer/poweredby_mediawiki_88x31.png" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88"/>
#      </a>
#     </li>
#    </ul>
#    <div style="clear: both;">
#    </div>
#   </footer>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.200","walltime":"0.259","ppvisitednodes":{"value":350,"limit":1000000},"postexpandincludesize":{"value":20530,"limit":2097152},"templateargumentsize":{"value":123,"limit":2097152},"expansiondepth":{"value":8,"limit":40},"expensivefunctioncount":{"value":0,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":14464,"limit":5000000},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["100.00%  200.889      1 -total"," 79.42%  159.555      1 Template:Reflist"," 59.78%  120.091      1 Template:Cite_news"," 11.06%   22.220      3 Template:Cite_periodical"," 10.09%   20.264      1 Template:Rupee","  8.36%   16.802      1 Template:Navbox","  4.37%    8.773      2 Template:INR","  1.69%    3.391      2 Template:Main_other"]},"scribunto":{"limitreport-timeusage":{"value":"0.097","limit":"10.000"},"limitreport-memusage":{"value":2498829,"limit":52428800}},"cachereport":{"origin":"mw1285","timestamp":"20201118174215","ttl":2592000,"transientcontent":false}}});});
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https:\/\/schema.org","@type":"Article","name":"Exchange rate history of the Indian rupee","url":"https:\/\/en.wikipedia.org\/wiki\/Exchange_rate_history_of_the_Indian_rupee","sameAs":"http:\/\/www.wikidata.org\/entity\/Q18387468","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q18387468","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2014-09-02T17:22:27Z","dateModified":"2020-11-09T04:02:53Z","headline":"Wikimedia list article"}
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":114,"wgHostname":"mw1269"});});
#   </script>
#  </body>
# </html>

# %%
# URL Title

title = soup.title.text
print(title)
# Out:
# Exchange rate history of the Indian rupee - Wikipedia

# %%
# Extracting Header from the URL

head = soup.find("div", attrs={"class": "mw-parser-output"})
head_data = head.table.find_all('th')

header = []
for i in head_data:
  header.append(i.text)

# Removing '\n' from last header
header[10] = header[10][:-1]

header
# Out:
# ['Year',
#  'SDR (average)',
#  'SDR (end year)',
#  'USD (average)',
#  'USD (end year)',
#  'GBP (average)',
#  'GBP (end year)',
#  'DM/EUR (average)',
#  'DM/EUR (end year)',
#  'JPY (average)',
#  'JPY (end year)']

# %%
# Extracting Column values from URL

curr_table = soup.find("div", attrs={"class": "mw-parser-output"})
curr_table_data = curr_table.table.find_all('td')

curr = []
for i in curr_table_data:
  curr.append(i.text)

curr
# Out:
# ['1974-75',
#  '9.6233',
#  '9.723',
#  '7.9408',
#  '7.794',
#  '18.8',
#  '18.776',
#  '3.1917',
#  '3.324',
#  '3',
#  '2.7\n',
#  '1975-76',
#  '10.3642',
#  '10.375',
#  '8.6825',
#  '8.973',
#  '18.3933',
#  '17.19',
#  '3.4458',
#  '3.535',
#  '3',
#  '3\n',
#  '1976-77',
#  '10.35',
#  '10.206',
#  '8.9775',
#  '8.804',
#  '15.5733',
#  '15.144',
#  '3.6308',
#  '3.686',
#  '3',
#  '3.2\n',
#  '1977-78',
#  '10.1605',
#  '10.43',
#  '8.5858',
#  '8.434',
#  '15.4292',
#  '15.656',
#  '3.8358',
#  '4.169',
#  '3.33',
#  '3.8\n',
#  '1978-79',
#  '10.4315',
#  '10.488',
#  '8.2267',
#  '8.15',
#  '15.9658',
#  '16.861',
#  '4.22',
#  '4.364',
#  '4',
#  '3.9\n',
#  '1979-80',
#  '10.4935',
#  '10.251',
#  '8.0975',
#  '8.193',
#  '17.655',
#  '17.753',
#  '4.4717',
#  '4.219',
#  '3.58',
#  '3.3\n',
#  '1980-81',
#  '10.1777',
#  '10.0620',
#  '7.9092',
#  '8.1900',
#  '18.5042',
#  '18.3800',
#  '4.1875',
#  '3.9000',
#  '3.7500',
#  '3.9000\n',
#  '1981-82',
#  '10.3354',
#  '10.4030',
#  '8.9683',
#  '9.3460',
#  '17.1096',
#  '16.6520',
#  '3.8607',
#  '3.8710',
#  '3.9400',
#  '3.8000\n',
#  '1982-83',
#  '10.5628',
#  '10.7540',
#  '9.6660',
#  '9.9700',
#  '16.1356',
#  '14.7460',
#  '3.9600',
#  '4.1090',
#  '3.8900',
#  '4.2000\n',
#  '1983-84',
#  '10.9405',
#  '11.3940',
#  '10.3400',
#  '10.7070',
#  '15.4174',
#  '15.4460',
#  '3.9402',
#  '4.1340',
#  '4.3800',
#  '4.8000\n',
#  '1984-85',
#  '11.9328',
#  '12.3210',
#  '11.8886',
#  '12.4300',
#  '14.8668',
#  '15.4500',
#  '3.9877',
#  '4.0190',
#  '4.8700',
#  '4.9000\n',
#  '1985-86',
#  '12.9232',
#  '13.9860',
#  '12.2349',
#  '12.3061',
#  '16.8467',
#  '18.2500',
#  '4.5553',
#  '5.3020',
#  '5.6200',
#  '6.8000\n',
#  '1986-87',
#  '15.4472',
#  '16.6210',
#  '12.7782',
#  '12.8882',
#  '15.2255',
#  '20.7490',
#  '6.2970',
#  '7.1620',
#  '8.0200',
#  '8.9000\n',
#  '1987-88',
#  '17.1208',
#  '17.9700',
#  '12.9658',
#  '13.0318',
#  '22.0872',
#  '24.3510',
#  '7.4004',
#  '7.8070',
#  '9.4100',
#  '10.3000\n',
#  '1988-89',
#  '19.2619',
#  '20.2080',
#  '14.4817',
#  '15.6630',
#  '25.5959',
#  '26.3990',
#  '8.0494',
#  '8.2590',
#  '11.3000',
#  '11.8000\n',
#  '1989-90',
#  '21.3684',
# Organizing Gathered Data

currency_table_data = []
l = []

for i in curr:
  
  if i[-1] != '\n':
    l.append(i)

  else:
    i = i[:-1]
    l.append(i)
    currency_table_data.append(l)
    l = []

currency_table_data
# Out:
# [['1974-75',
#   '9.6233',
#   '9.723',
#   '7.9408',
#   '7.794',
#   '18.8',
#   '18.776',
#   '3.1917',
#   '3.324',
#   '3',
#   '2.7'],
#  ['1975-76',
#   '10.3642',
#   '10.375',
#   '8.6825',
#   '8.973',
#   '18.3933',
#   '17.19',
#   '3.4458',
#   '3.535',
#   '3',
#   '3'],
#  ['1976-77',
#   '10.35',
#   '10.206',
#   '8.9775',
#   '8.804',
#   '15.5733',
#   '15.144',
#   '3.6308',
#   '3.686',
#   '3',
#   '3.2'],
#  ['1977-78',
#   '10.1605',
#   '10.43',
#   '8.5858',
#   '8.434',
#   '15.4292',
#   '15.656',
#   '3.8358',
#   '4.169',
#   '3.33',
#   '3.8'],
#  ['1978-79',
#   '10.4315',
#   '10.488',
#   '8.2267',
#   '8.15',
#   '15.9658',
#   '16.861',
#   '4.22',
#   '4.364',
#   '4',
#   '3.9'],
#  ['1979-80',
#   '10.4935',
#   '10.251',
#   '8.0975',
#   '8.193',
#   '17.655',
#   '17.753',
#   '4.4717',
#   '4.219',
#   '3.58',
#   '3.3'],
#  ['1980-81',
#   '10.1777',
#   '10.0620',
#   '7.9092',
#   '8.1900',
#   '18.5042',
#   '18.3800',
#   '4.1875',
#   '3.9000',
#   '3.7500',
#   '3.9000'],
#  ['1981-82',
#   '10.3354',
#   '10.4030',
#   '8.9683',
#   '9.3460',
#   '17.1096',
#   '16.6520',
#   '3.8607',
#   '3.8710',
#   '3.9400',
#   '3.8000'],
#  ['1982-83',
#   '10.5628',
#   '10.7540',
#   '9.6660',
#   '9.9700',
#   '16.1356',
#   '14.7460',
#   '3.9600',
#   '4.1090',
#   '3.8900',
#   '4.2000'],
#  ['1983-84',
#   '10.9405',
#   '11.3940',
#   '10.3400',
#   '10.7070',
#   '15.4174',
#   '15.4460',
#   '3.9402',
#   '4.1340',
#   '4.3800',
#   '4.8000'],
#  ['1984-85',
#   '11.9328',
#   '12.3210',
#   '11.8886',
#   '12.4300',
#   '14.8668',
#   '15.4500',
#   '3.9877',
#   '4.0190',
#   '4.8700',
#   '4.9000'],
#  ['1985-86',
#   '12.9232',
#   '13.9860',
#   '12.2349',
#   '12.3061',
#   '16.8467',
#   '18.2500',
#   '4.5553',
#   '5.3020',
#   '5.6200',
#   '6.8000'],
#  ['1986-87',
#   '15.4472',
#   '16.6210',
#   '12.7782',
#   '12.8882',
#   '15.2255',
#   '20.7490',
#   '6.2970',
#   '7.1620',
#   '8.0200',
#   '8.9000'],
#  ['1987-88',
#   '17.1208',
#   '17.9700',
#   '12.9658',
#   '13.0318',
#   '22.0872',
#   '24.3510',
#   '7.4004',
#   '7.8070',
#   '9.4100',
#   '10.3000'],
#  ['1988-89',
#   '19.2619',
#   '20.2080',
#   '14.4817',
#   '15.6630',
#   '25.5959',
#   '26.3990',
#   '8.0494',
#   '8.2590',
#   '11.3000',
#   '11.8000'],
#  ['1989-90',
#   '21.3684',
#   '22.4090',
#   '16.6492',
#   '17.3248',
#   '26.9179',
#   '28.3010',
#   '9.0922',
#   '10.1670',
#   '11.6600',
#   '11.0000'],
#  ['1990-91',
#   '24.8431',
#   '26.4140',
#   '17.9428',
#   '19.6429',
#   '33.1930',
#   '34.0500',
#   '11.4351',
#   '11.4270',
#   '12.7900',
#   '13.9000'],
#  ['1991-92',
#   '33.4325',
#   '35.5143',
#   '24.4737',
#   '31.2256',
#   '42.5151',
#   '53.6913',
#   '14.6248',
#   '18.3501',
#   '18.4400',
#   '23.2800'],
#  ['1992-93',
#   '37.1415',
#   '43.6511',
#   '30.6488',
#   '31.2354',
#   '51.6858',
#   '46.6200',
#   '19.5877',
#   '19.2864',
#   '24.5900',
#   '26.9900'],
#  ['1993-94',
#   '43.8863',
#   '44.3133',
#   '31.3655',
#   '31.3725',
#   '47.2064',
#   '46.5200',
#   '18.7403',
#   '18.7575',
#   '29.1100',
#   '35.5200'],
#  ['1994-95',
#   '45.7908',
#   '49.1558',
#   '31.3986',
#   '31.4950',
#   '48.8211',
#   '50.5650',
#   '20.2017',
#   '22.3600',
#   '31.6341',
#   '35.2888'],
#  ['1995-96',
#   '50.4768',
#   '50.1633',
#   '33.4498',
#   '34.3500',
#   '52.3526',
#   '52.4300',
#   '23.3993',
#   '23.3038',
#   '34.8425',
#   '32.2975'],
#  ['1996-97',
#   '50.8858',
#   '49.8032',
#   '35.4999',
#   '35.9150',
#   '56.3646',
#   '58.6938',
#   '22.9244',
#   '21.3863',
#   '31.5879',
#   '28.9463'],
#  ['1997-98',
#   '50.6735',
#   '52.7677',
#   '37.1648',
#   '39.4950',
#   '61.0240',
#   '66.1638',
#   '20.9613',
#   '21.3350',
#   '30.2990',
#   '29.7813'],
#  ['1998-99',
#   '57.5129',
#   '57.6132',
#   '42.0706',
#   '42.4350',
#   '69.5505',
#   '68.3588',
#   '24.1792',
#   '23.2863',
#   '33.1341',
#   '35.3263'],
#  ['1999-00',
#   '58.9335',
#   '58.7505',
#   '43.3327',
#   '43.6050',
#   '69.8510',
#   '69.5100',
#   '44.7909',
#   '41.7975',
#   '39.0606',
#   '41.4825'],
#  ['2000-01',
#   '59.5459',
#   '58.7969',
#   '45.6844',
#   '46.6400',
#   '67.5522',
#   '66.5788',
#   '41.4832',
#   '41.0113',
#   '41.4052',
#   '37.4338'],
#  ['2001-02',
#   '60.2150',
#   '60.8446',
#   '47.6919',
#   '48.8000',
#   '68.3189',
#   '69.5863',
#   '42.1811',
#   '42.6438',
#   '38.1790',
#   '36.8063'],
#  ['2002-03',
#   '64.1257',
#   '65.2550',
#   '48.3953',
#   '47.5050',
#   '74.8193',
#   '74.9225',
#   '48.0901',
#   '51.4925',
#   '39.7363',
#   '39.8925'],
#  ['2003-04',
#   '65.6876',
#   '64.2393',
#   '45.9516',
#   '43.4450',
#   '77.7389',
#   '79.6813',
#   '53.9896',
#   '53.1725',
#   '40.7077',
#   '41.6725'],
#  ['2004-05',
#   '66.9282',
#   '66.0987',
#   '44.9315',
#   '43.7550',
#   '82.8644',
#   '82.1125',
#   '56.5523',
#   '56.5863',
#   '41.8046',
#   '40.8075'],
#  ['2005-06',
#   '64.4898',
#   '64.2566',
#   '44.2735',
#   '44.6050',
#   '79.0472',
#   '77.7963',
#   '53.9124',
#   '54.1875',
#   '39.1438',
#   '38.0188'],
#  ['2006-07',
#   '67.2538',
#   '65.8289',
#   '45.2849',
#   '43.5950',
#   '85.7274',
#   '85.5938',
#   '58.1110',
#   '58.1513',
#   '38.7975',
#   '37.0338'],
#  ['2007-08',
#   '62.6506',
#   '65.7307',
#   '40.2410',
#   '39.9850',
#   '80.8016',
#   '79.5138',
#   '56.9906',
#   '63.0963',
#   '35.2896',
#   '40.0650'],
#  ['2008-09',
#   '71.2770',
#   '76.1742',
#   '45.9170',
#   '50.9450',
#   '78.4485',
#   '72.8575',
#   '65.1345',
#   '67.4713',
#   '46.0521',
#   '51.8900'],
#  ['2009-10',
#   '73.7333',
#   '68.5335',
#   '47.4166',
#   '45.1350',
#   '75.8861',
#   '68.0188',
#   '67.0843',
#   '60.5913',
#   '51.1261',
#   '48.4338'],
#  ['2010-11',
#   '69.7228',
#   '70.7930',
#   '45.5768',
#   '44.6450',
#   '70.8853',
#   '71.9163',
#   '60.2181',
#   '63.2350',
#   '53.2963',
#   '54.0175'],
#  ['2011-12',
#   '75.3132',
#   '79.2512',
#   '47.9229',
#   '51.1600',
#   '76.3912',
#   '81.7975',
#   '65.8939',
#   '68.3550',
#   '60.7484',
#   '62.4250'],
#  ['2012-13',
#   '83.0262',
#   '81.4764',
#   '53.2112',
#   '54.2323',
#   '85.9713',
#   '82.3209',
#   '70.0693',
#   '69.5438',
#   '65.8530',
#   '57.7600'],
#  ['2013-14',
#   '92.2602',
#   '92.7790',
#   '60.5019',
#   '60.0998',
#   '96.3058',
#   '99.8498',
#   '60.4026',
#   '58.8300',
#   '81.1745',
#   '82.5765'],
#  ['2014-15',
#   '90.7955',
#   '86.3431',
#   '61.1436',
#   '62.5908',
#   '98.5731',
#   '92.4591',
#   '55.8266',
#   '52.1100',
#   '77.5209',
#   '67.5104'],
#  ['2015-16',
#   '91.3452',
#   '93.4510',
#   '65.4685',
#   '66.3329',
#   '98.7260',
#   '95.0882',
#   '54.5934',
#   '59.0600',
#   '72.2894',
#   '75.0955'],
#  ['2016-17',
#   '92.6156',
#   '87.9763',
#   '67.0720',
#   '64.8386',
#   '87.6897',
#   '80.8797',
#   '62.0350',
#   '57.9600',
#   '73.6087',
#   '69.2476'],
#  ['2017-18',
#   '90.8989',
#   '94.8065',
#   '64.4549',
#   '65.0441',
#   '85.5129',
#   '92.2846',
#   '58.1822',
#   '61.5400',
#   '75.4378',
#   '80.6222'],
#  ['2018-19',
#   '98.0361',
#   '96.0273',
#   '69.9229',
#   '69.1713',
#   '91.7865',
#   '90.4756',
#   '63.0468',
#   '62.5200',
#   '80.9580',
#   '77.7024']]

# %%
# Converting list to Dataframe

df_cr = pd.DataFrame(currency_table_data,columns = header)

# %%
# Dataframe
df_cr.head()
# Out:
#       Year SDR (average)  ... JPY (average) JPY (end year)
# 0  1974-75        9.6233  ...             3            2.7
# 1  1975-76       10.3642  ...             3              3
# 2  1976-77         10.35  ...             3            3.2
# 3  1977-78       10.1605  ...          3.33            3.8
# 4  1978-79       10.4315  ...             4            3.9
#
# [5 rows x 11 columns]

# %%
# Dataframe Columns
df_cr.columns
# Out:
# Index(['Year', 'SDR (average)', 'SDR (end year)', 'USD (average)',
#        'USD (end year)', 'GBP (average)', 'GBP (end year)', 'DM/EUR (average)',
#        'DM/EUR (end year)', 'JPY (average)', 'JPY (end year)'],
#       dtype='object')

# %%
# About Dataframe
df_cr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               45 non-null     object
#  1   SDR (average)      45 non-null     object
#  2   SDR (end year)     45 non-null     object
#  3   USD (average)      45 non-null     object
#  4   USD (end year)     45 non-null     object
#  5   GBP (average)      45 non-null     object
#  6   GBP (end year)     45 non-null     object
#  7   DM/EUR (average)   45 non-null     object
#  8   DM/EUR (end year)  45 non-null     object
#  9   JPY (average)      45 non-null     object
#  10  JPY (end year)     45 non-null     object
# dtypes: object(11)
# memory usage: 4.0+ KB

# %%
# Dropping Columns
df_cr.drop(df_cr.columns[[1,2,3,5,6,7,8,9,10]],axis = 1,inplace = True)

# Renaming Column
df_cr.rename(columns={'USD (end year)': 'USD'},inplace = True)

# Changing 'Year' Data
df_cr['Year'] = df_cr['Year'].map(lambda x: str(x)[:-3])

# Dtype Conversion
df_cr['Year'] = df_cr['Year'].astype('int64')
df_cr['USD'] = df_cr['USD'].astype('float64')

# %%
# Confirmation

df_cr.dtypes
# Out:
# Year      int64
# USD     float64
# dtype: object

# %%
# Final Dataframe
df_cr
# Out:
#     Year      USD
# 0   1974   7.7940
# 1   1975   8.9730
# 2   1976   8.8040
# 3   1977   8.4340
# 4   1978   8.1500
# 5   1979   8.1930
# 6   1980   8.1900
# 7   1981   9.3460
# 8   1982   9.9700
# 9   1983  10.7070
# 10  1984  12.4300
# 11  1985  12.3061
# 12  1986  12.8882
# 13  1987  13.0318
# 14  1988  15.6630
# 15  1989  17.3248
# 16  1990  19.6429
# 17  1991  31.2256
# 18  1992  31.2354
# 19  1993  31.3725
# 20  1994  31.4950
# 21  1995  34.3500
# 22  1996  35.9150
# 23  1997  39.4950
# 24  1998  42.4350
# 25  1999  43.6050
# 26  2000  46.6400
# 27  2001  48.8000
# 28  2002  47.5050
# 29  2003  43.4450
# 30  2004  43.7550
# 31  2005  44.6050
# 32  2006  43.5950
# 33  2007  39.9850
# 34  2008  50.9450
# 35  2009  45.1350
# 36  2010  44.6450
# 37  2011  51.1600
# 38  2012  54.2323
# 39  2013  60.0998
# 40  2014  62.5908
# 41  2015  66.3329
# 42  2016  64.8386
# 43  2017  65.0441
# 44  2018  69.1713

# %%
# Saving as CSV
df_cr.to_csv('/content/drive/MyDrive/Colab Notebooks/'+ title +'.csv' ,index = False)
